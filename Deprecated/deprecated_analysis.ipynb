# %% [markdown]
# # Deprecated Aspects of Analysis

# %% [markdown]
# ### Extracting Song Data Using Spotipy
#
# To broaden the available data and areas for analysis, I wanted to incorporate another dataset that can be joined to the Award Show Winner dataset above. Therefore, I thought it would be suitable to gather characteristics about a song which would allow us to see what characteristics are shared amongst winning songs, the types of songs that are popular in certain seasons, etc.

# %% [markdown]
# #### Spotipy Authentication
#
# To perform API calls, I need to authenticate myself to use the Spotify and access the dashboard for the needed keys.

# %%
import json
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

with open('.keys/spotipy.json', 'r') as file:
    data = json.load(file)

auth_manager = SpotifyClientCredentials(client_id=data["client_id"], client_secret=data["client_secret"])
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
data = sp.search('track:BonVoyage artist:Dreamcatcher year:2000-2023', limit=1, type=['track', 'artist'], market='KR')['tracks']['items']
print(f"{data[0]['artists'][0]['name']} - {data[0]['name']}: {data[0]['id']}\n")
# Out:
# Dreamcatcher - BONVOYAGE: 3Jnwl9zlbFNEqKQjydxLxe

# %%
uniq_tracks = list(set(all_show_df_winners["Search Query"]))
uniq_tracks
# Out:
# ['track:Love artist:Monsta X year:2000-2022',
#  'track:Way 4 Luv artist:Plave year:2000-2024',
#  'track:Perfect Night artist:Le Sserafim year:2000-2023',
#  'track:Deja Vu artist:Tomorrow X Together year:2000-2024',
#  "track:Killin' Me Good artist:Jihyo year:2000-2023",
#  'track:Be There For Me artist:NCT 127 year:2000-2024',
#  'track:Lighthouse artist:Tempest year:2000-2024',
#  'track:S-Class artist:Stray Kids year:2000-2023',
#  'track:Cream Soda artist:Exo year:2000-2023',
#  'track:Birthday artist:Red Velvet year:2000-2022',
#  'track:Love Shhh! artist:Jo Yuri year:2000-2022',
#  'track:Selfish artist:YooA year:2000-2022',
#  'track:Eunoia artist:Billlie year:2000-2023',
#  'track:Erase Me artist:Oneus year:2000-2023',
#  'track:Loser artist:AB6IX year:2000-2023',
#  'track:Hit the Floor artist:TripleS year:2000-2024',
#  'track:Give Me That artist:WayV year:2000-2024',
#  'track:Girls Never Die artist:TripleS year:2000-2024',
#  'track:OMG artist:NewJeans year:2000-2023',
#  'track:Whisper artist:The Boyz year:2000-2022',
#  'track:Tipi-tap artist:Kep1er year:2000-2024',
#  'track:Flower artist:Jisoo year:2000-2023',
#  'track:Strategy artist:Twice year:2000-2024',
#  'track:Good Boy Gone Bad artist:TXT year:2000-2022',
#  'track:Baggy Jeans artist:NCT U year:2000-2023',
#  'track:Slow Dancing artist:V year:2000-2023',
#  'track:That That artist:Psy year:2000-2022',
#  'track:Future Perfect artist:Enhypen year:2000-2022',
#  'track:Warmth artist:Lim Young-woong year:2000-2024',
#  'track:Super Lady artist:(G)I-dle year:2000-2024',
#  'track:XO (Only If You Say Yes) artist:Enhypen year:2000-2024',
#  'track:Armageddon artist:Aespa year:2000-2024',
#  'track:Little Light artist:Doyoung year:2000-2024',
#  'track:Body artist:Highlight year:2000-2024',
#  'track:Fate artist:(G)I-dle year:2000-2024',
#  'track:But I artist:Solar year:2000-2024',
#  "track:Eve, Psyche & the Bluebeard's Wife artist:Le Sserafim year:2000-2023",
#  'track:Love Me Again artist:V year:2000-2023',
#  'track:ETA artist:NewJeans year:2000-2023',
#  'track:Who artist:Jimin year:2000-2024',
#  'track:Cheeky Icy Thang artist:STAYC year:2000-2024',
#  'track:Sugar Rush Ride artist:TXT year:2000-2023',
#  'track:Earth, Wind & Fire artist:BoyNextDoor year:2000-2024',
#  'track:Beautiful Monster artist:STAYC year:2000-2022',
#  'track:Ggum artist:Yeonjun year:2000-2024',
#  'track:Get Loud artist:Kiss of Life year:2000-2024',
#  'track:DM artist:Fromis 9 year:2000-2022',
#  'track:♡Ticon artist:CSR year:2000-2022',
#  'track:Love 119 artist:Riize year:2000-2024',
#  'track:Switch artist:Kim Woo Seok year:2000-2022',
#  'track:Walkin on Water artist:Stray Kids year:2000-2024',
#  'track:Bubble artist:STAYC year:2000-2023',
#  "track:When I'm With You artist:NCT Dream year:2000-2024",
#  'track:Dilemma artist:Apink year:2000-2022',
#  'track:Fighting artist:BSS year:2000-2023',
#  'track:Songbird artist:NCT Wish year:2000-2024',
#  'track:Pink Venom artist:Blackpink year:2000-2022',
#  'track:Beautiful Liar artist:Monsta X year:2000-2023',
#  'track:Easy artist:Le Sserafim year:2000-2024',
#  'track:Antifragile artist:Le Sserafim year:2000-2022',
#  'track:Untouchable artist:Itzy year:2000-2024',
#  'track:Taxi artist:Jo Yuri year:2000-2023',
#  "track:If I'm S, Can You Be My N? artist:TWS year:2000-2024",
#  'track:The Song artist:BtoB year:2000-2022',
#  'track:#menow artist:Fromis 9 year:2000-2023',
#  'track:Fact Check artist:NCT 127 year:2000-2023',
#  'track:Tomboy artist:(G)I-dle year:2000-2022',
#  'track:Jikjin artist:Treasure year:2000-2022',
#  'track:Sad Song artist:P1Harmony year:2000-2024',
#  'track:Shooting Star artist:Kep1er year:2000-2024',
#  'track:Dash artist:Nmixx year:2000-2024',
#  'track:CBZ (Prime Time) artist:BSS year:2000-2025',
#  'track:Crazy Form artist:Ateez year:2000-2023',
#  'track:If I Say, I Love You artist:BoyNextDoor year:2000-2025',
#  'track:Feel My Rhythm artist:Red Velvet year:2000-2022',
#  'track:Ay-Yo artist:NCT 127 year:2000-2023',
#  'track:Maison artist:Dreamcatcher year:2000-2022',
#  'track:Either Way artist:Ive year:2000-2023',
#  'track:Spring Breeze artist:Kim Jae-hwan year:2000-2023',
#  'track:Step Back artist:Got the Beat year:2000-2022',
#  'track:Bite Me artist:Enhypen year:2000-2023',
#  'track:Lip Gloss artist:The Boyz year:2000-2023',
#  'track:Do or Die artist:Lim Young-woong year:2000-2023',
#  'track:2 Baddies artist:NCT 127 year:2000-2022',
#  'track:Bam Yang Gang artist:Bibi year:2000-2024',
#  'track:Dragon artist:Tempest year:2000-2022',
#  'track:3D artist:Jung Kook year:2000-2023',
#  'track:Supernova artist:Aespa year:2000-2024',
#  'track:ISTJ artist:NCT Dream year:2000-2023',
#  'track:Klaxon artist:(G)I-dle year:2000-2024',
#  'track:Love Lee artist:AKMU year:2000-2023',
#  'track:Bye My Monster artist:ONF year:2000-2024',
#  'track:Fri(end)s artist:V year:2000-2024',
#  'track:Frequency artist:WayV year:2000-2024',
#  'track:Yet to Come artist:BTS year:2000-2022',
#  'track:Girls artist:Aespa year:2000-2022',
#  'track:Smoothie artist:NCT Dream year:2000-2024',
#  'track:하늘 여행 artist:Lee Chan-won year:2000-2024',
#  'track:See That? artist:Nmixx year:2000-2024',
#  'track:Small Girl artist:Lee Young-ji year:2000-2024',
#  'track:Daydream artist:Highlight year:2000-2022',
#  'track:The Flash artist:Kwon Eunbi year:2000-2023',
#  'track:Tap Tap artist:Verivery year:2000-2022',
#  'track:Rebel Heart artist:Ive year:2000-2025',
#  'track:Watch It artist:The Boyz year:2000-2023',
#  'track:Same Scent artist:Oneus year:2000-2022',
#  'track:Set Me Free Pt. 2 artist:Jimin year:2000-2023',
#  'track:Supersonic artist:Fromis 9 year:2000-2024',
#  'track:Pump Up the Volume artist:Plave year:2000-2024',
#  'track:Spot! artist:Zico year:2000-2024',
#  'track:Frequency(Korean Ver.) artist:WayV year:2000-2024',
#  'track:Pleasure Shop artist:Key year:2000-2024',
#  'track:Beatbox artist:NCT Dream year:2000-2022',
#  'track:Love Dive artist:Ive year:2000-2022',
#  'track:Over the Moon artist:Tomorrow X Together year:2000-2024',
#  'track:Wish artist:NCT Wish year:2000-2024',
#  'track:Shut Down artist:Blackpink year:2000-2022',
#  'track:Apt. artist:Rosé&Bruno Mars year:2000-2025',
#  'track:_World artist:Seventeen year:2000-2022',
#  'track:Set Me Free artist:Twice year:2000-2023',
#  'track:Feel the Pop artist:Zerobaseone year:2000-2024',
#  'track:Cheshire artist:Itzy year:2000-2022',
#  'track:Ice on My Teeth artist:Ateez year:2000-2024',
#  "track:Don't Worry, Be Happy artist:SF9 year:2000-2024",
#  'track:INVU artist:Taeyeon year:2000-2022',
#  'track:Home Sweet Home artist:G-Dragon year:2000-2024',
#  'track:Candy artist:NCT Dream year:2000-2022',
#  'track:Fearless artist:Le Sserafim year:2000-2022',
#  'track:Guerrilla artist:Ateez year:2000-2022',
#  'track:Lalalala artist:Stray Kids year:2000-2023',
#  'track:Party Rock artist:Cravity year:2000-2022',
#  'track:Glitch Mode artist:NCT Dream year:2000-2022',
#  'track:Good So Bad artist:Zerobaseone year:2000-2024',
#  'track:Run2U artist:STAYC year:2000-2022',
#  'track:Candy Sugar Pop artist:Astro year:2000-2022',
#  'track:Stay This Way artist:Fromis 9 year:2000-2022',
#  'track:Cake artist:Itzy year:2000-2023',
#  'track:Vroom Vroom artist:Tempest year:2000-2023',
#  'track:Melt Down artist:Day6 year:2000-2024',
#  'track:When I Move artist:Kara year:2000-2022',
#  'track:Up artist:Aespa year:2000-2024',
#  'track:Real Love artist:Oh My Girl year:2000-2022',
#  'track:풍등 artist:Lee Chan-won year:2000-2023',
#  'track:Pop! artist:Nayeon year:2000-2022',
#  'track:Baila Conmigo artist:Oneus year:2000-2023',
#  'track:Sheesh artist:BabyMonster year:2000-2024',
#  'track:Super Shy artist:NewJeans year:2000-2023',
#  'track:Smeraldo Garden Marching Band artist:Jimin year:2000-2024',
#  'track:ABCD artist:Nayeon year:2000-2024',
#  'track:Seoul (Such a Beautiful City) artist:H1-Key year:2000-2023',
#  'track:Love Wins All artist:IU year:2000-2024',
#  'track:London Boy artist:Lim Young-woong year:2000-2022',
#  'track:Vibe artist:Taeyang year:2000-2023',
#  'track:God of Music artist:Seventeen year:2000-2023',
#  'track:Upside Down artist:Kang Daniel year:2000-2022',
#  'track:Chill Kill artist:Red Velvet year:2000-2023',
#  'track:Up! artist:Kep1er year:2000-2022',
#  'track:Happy artist:Day6 year:2000-2024',
#  'track:But Sometimes artist:BoyNextDoor year:2000-2023',
#  'track:Sticky artist:Kiss of Life year:2000-2024',
#  'track:Pineapple Slice artist:Baekhyun year:2000-2024',
#  'track:Automatic artist:Vanner year:2000-2024',
#  'track:Grain of Sand artist:Lim Young-woong year:2000-2023',
#  'track:To. X artist:Taeyeon year:2000-2024',
#  'track:Hype Boy artist:NewJeans year:2000-2023',
#  'track:If We Ever Meet Again artist:Lim Young-woong year:2000-2022',
#  'track:Boom Boom Bass artist:Riize year:2000-2024',
#  'track:Nice Guy artist:BoyNextDoor year:2000-2024',
#  "track:Feelin' Like artist:Pentagon year:2000-2022",
#  'track:Still Life artist:Big Bang year:2000-2022',
#  'track:I Am artist:Ive year:2000-2023',
#  'track:Apt. artist:Rosé&Bruno Mars year:2000-2024',
#  'track:Queencard artist:(G)I-dle year:2000-2023',
#  'track:On the Street artist:J-Hope&J. Cole year:2000-2023',
#  'track:Maniac artist:Stray Kids year:2000-2022',
#  'track:Kitsch artist:Ive year:2000-2023',
#  'track:Make Me Happy artist:Wheein year:2000-2022',
#  'track:Summer Comes artist:Oh My Girl year:2000-2023',
#  'track:Ditto artist:NewJeans year:2000-2023',
#  'track:Hello artist:Jaechan year:2000-2023',
#  'track:Halazia artist:Ateez year:2000-2023',
#  'track:Attention artist:NewJeans year:2000-2022',
#  'track:Whiplash artist:Aespa year:2000-2024',
#  'track:Trigger artist:The Boyz year:2000-2024',
#  'track:Crazy artist:Le Sserafim year:2000-2024',
#  'track:Ugly artist:Evnne year:2000-2024',
#  'track:Groovy artist:Cravity year:2000-2023',
#  'track:Nxde artist:(G)I-dle year:2000-2022',
#  'track:Plot Twist artist:TWS year:2000-2024',
#  'track:Sugar Rush Ride artist:Tomorrow X Together year:2000-2023',
#  'track:Unforgiven artist:Le Sserafim year:2000-2023',
#  'track:Guilty artist:Taemin year:2000-2023',
#  'track:Like Crazy artist:Jimin year:2000-2023',
#  'track:The Astronaut artist:Jin year:2000-2022',
#  'track:Chk Chk Boom artist:Stray Kids year:2000-2024',
#  'track:Maestro artist:Seventeen year:2000-2024',
#  'track:Smiley artist:Yena year:2000-2022',
#  'track:Alone artist:Highlight year:2000-2022',
#  'track:Standing Next to You artist:Jung Kook year:2000-2023',
#  'track:Event Horizon artist:Younha year:2000-2022',
#  'track:Hello, My First Love artist:The Wind year:2000-2024',
#  'track:Sparkling artist:Chungha year:2000-2022',
#  'track:Teddy Bear artist:STAYC year:2000-2023',
#  'track:Perfume artist:NCT DoJaeJung year:2000-2023',
#  'track:Love Potion artist:N.SSign year:2000-2025',
#  'track:Wa Da Da artist:Kep1er year:2000-2022',
#  'track:Magnetic artist:Illit year:2000-2024',
#  'track:Bop Bop! artist:Viviz year:2000-2022',
#  'track:Case 143 artist:Stray Kids year:2000-2022',
#  'track:Chasing That Feeling artist:TXT year:2000-2023',
#  'track:Flip That artist:Loona year:2000-2022',
#  'track:Baddie artist:Ive year:2000-2023',
#  'track:BONVOYAGE artist:Dreamcatcher year:2000-2023',
#  'track:Rover artist:Kai year:2000-2023',
#  'track:After Like artist:Ive year:2000-2022',
#  'track:The First Snow artist:Exo year:2000-2023',
#  'track:Slay artist:Everglow year:2000-2023',
#  'track:Dive Into artist:Han Seung-woo year:2000-2023',
#  'track:Work artist:Ateez year:2000-2024',
#  'track:Electric Shock artist:Kang Daniel year:2000-2024',
#  'track:Closer Than This artist:Jimin year:2000-2024',
#  'track:Nectar artist:The Boyz year:2000-2024',
#  'track:Super artist:Seventeen year:2000-2023',
#  'track:My Name is Malguem artist:QWER year:2000-2024',
#  'track:Walkin on Water artist:Stray Kids year:2000-2025',
#  'track:Love or Die artist:Cravity year:2000-2024',
#  "track:Killin' It artist:P1Harmony year:2000-2024",
#  'track:Spicy artist:Aespa year:2000-2023',
#  'track:O (Circle) artist:Onew year:2000-2023',
#  'track:Drive artist:Miyeon year:2000-2022',
#  'track:Steady artist:NCT Wish year:2000-2024',
#  'track:Walk artist:NCT 127 year:2000-2024',
#  'track:Uh-Heung artist:DKZ year:2000-2022',
#  'track:Drama artist:Aespa year:2000-2023',
#  'track:Bouncy (K-Hot Chilli Peppers) artist:Ateez year:2000-2023',
#  'track:Love Me Like This artist:Nmixx year:2000-2023',
#  'track:At That Moment artist:WSG Wannabe (Gaya-G) year:2000-2022',
#  'track:Future Perfect (Pass the MIC) artist:Enhypen year:2000-2022',
#  'track:Heartris artist:NiziU year:2000-2023',
#  'track:Hot artist:Seventeen year:2000-2022',
#  'track:Sweet Venom artist:Enhypen year:2000-2023',
#  'track:Mantra artist:Jennie year:2000-2024',
#  'track:Roar artist:The Boyz year:2000-2023',
#  'track:Hard artist:Shinee year:2000-2023',
#  'track:Love, Money, Fame artist:Seventeen year:2000-2024',
#  'track:Take Two artist:BTS year:2000-2023',
#  'track:In Bloom artist:Zerobaseone year:2000-2023',
#  'track:Drama artist:Aespa year:2000-2024',
#  'track:Predator artist:Lee Gi-kwang year:2000-2023',
#  'track:Sneakers artist:Itzy year:2000-2022',
#  'track:How Sweet artist:NewJeans year:2000-2024',
#  'track:Blessed-Cursed artist:Enhypen year:2000-2022',
#  'track:Eleven artist:Ive year:2000-2022',
#  'track:Universe artist:NCT U year:2000-2022',
#  'track:Home Sweet Home artist:G-Dragon year:2000-2025',
#  'track:Drunken Confession artist:Kim Min-seok year:2000-2022',
#  'track:Winter Sleep artist:IU year:2000-2022',
#  'track:Seven artist:Jung Kook year:2000-2023',
#  'track:To. X artist:Taeyeon year:2000-2023',
#  'track:Smoke artist:Jaehyun year:2000-2024']

# %%
uniq_song_ids = {
    ## Song Query : song ID
}

# %%
def extract_song_ids(uniq_tracks, uniq_song_ids):
    for i in range(len(uniq_tracks)):
        if uniq_tracks[i] not in uniq_song_ids:
            print(f"Searching for: {uniq_tracks[i]}")
            data = sp.search(uniq_tracks[i], limit=1, type=['track', 'artist'], market='KR')['tracks']['items']
            print(f"{data[0]['artists'][0]['name']} - {data[0]['name']}: {data[0]['id']}\n")
            uniq_song_ids[uniq_tracks[i]] = data[0]['id']
    return uniq_song_ids

# %%
uniq_song_ids = extract_song_ids(uniq_tracks, uniq_song_ids)
# Out:
# Searching for: track:Love artist:Monsta X year:2000-2022
# MONSTA X - Love Killa: 3sPju6MEJhk7Sz8dsRBkLQ
#
# Searching for: track:Way 4 Luv artist:Plave year:2000-2024
# PLAVE - WAY 4 LUV: 1T6xi2QrnmwaebXGvWAjLg
#
# Searching for: track:Perfect Night artist:Le Sserafim year:2000-2023
# LE SSERAFIM - Perfect Night: 74X2u8JMVooG2QbjRxXwR8
#
# Searching for: track:Deja Vu artist:Tomorrow X Together year:2000-2024
# TOMORROW X TOGETHER - Deja Vu: 3aAnwyBJY9OLNLqSgd4fZU
#
# Searching for: track:Killin' Me Good artist:Jihyo year:2000-2023
# JIHYO - Killin’ Me Good: 3gafQxekHAbM52PxdX9SDR
#
# Searching for: track:Be There For Me artist:NCT 127 year:2000-2024
# NCT 127 - Be There For Me: 1k5b4EAewkP3sqLWcCmWRQ
#
# Searching for: track:Lighthouse artist:Tempest year:2000-2024
# TEMPEST - LIGHTHOUSE: 6Zv31tXdpqXPuMXIT4Pq7p
#
# Searching for: track:S-Class artist:Stray Kids year:2000-2023
# Stray Kids - 특 S-Class: 54zRGA28tVRKRmFCpywWko
#
# Searching for: track:Cream Soda artist:Exo year:2000-2023
# EXO - Cream Soda: 42h7yc9Rda1IOMYLACVgld
#
# Searching for: track:Birthday artist:Red Velvet year:2000-2022
# Red Velvet - Birthday: 4LJgBT9yo0beHlaBesCFEv
#
# Searching for: track:Love Shhh! artist:Jo Yuri year:2000-2022
# JO YURI - Love Shhh!: 00vy9aiFjxMfnKniQAYzrC
#
# Searching for: track:Selfish artist:YooA year:2000-2022
# YooA - Selfish: 4XLrS9QHUqGuPNDyzViQxt
#
# Searching for: track:Eunoia artist:Billlie year:2000-2023
# Billlie - EUNOIA: 0a56sRmdBxCON2nkEgjDqC
#
# Searching for: track:Erase Me artist:Oneus year:2000-2023
# ONEUS - ERASE ME: 1K2cYJekjVTqjSPJdLhGQB
#
# Searching for: track:Loser artist:AB6IX year:2000-2023
# AB6IX - LOSER: 2jSKhV7zSImRqT4jBCFnEE
#
# Searching for: track:Hit the Floor artist:TripleS year:2000-2024
# tripleS - Hit the Floor: 7CSNTKPHjDreo1hBA5PRSN
#
# Searching for: track:Give Me That artist:WayV year:2000-2024
# WayV - Give Me That - Korean Version: 4Ta60nUTt3W1JU0AxctPyG
#
# Searching for: track:Girls Never Die artist:TripleS year:2000-2024
# tripleS - Girls Never Die: 0Ol7uhYjodbXAKKarXdn6r
#
# Searching for: track:OMG artist:NewJeans year:2000-2023
# NewJeans - OMG: 65FftemJ1DbbZ45DUfHJXE
#
# Searching for: track:Whisper artist:The Boyz year:2000-2022
# THE BOYZ - WHISPER: 52uklJhyhJbLvHrgkiqCaW
#
# Searching for: track:Tipi-tap artist:Kep1er year:2000-2024
# Kep1er - TIPI-TAP: 0SCHvh0ZqVd2Wcq2l4kzai
#
# Searching for: track:Flower artist:Jisoo year:2000-2023
# JISOO - FLOWER: 0bC7GKnxh9W9JIvJ6HVWxc
#
# Searching for: track:Strategy artist:Twice year:2000-2024
# TWICE - Strategy (feat. Megan Thee Stallion): 5111HV1Fb6hfeHH0b7VYMm
#
# Searching for: track:Good Boy Gone Bad artist:TXT year:2000-2022
# TOMORROW X TOGETHER - Good Boy Gone Bad: 1HsSIPLTQT354yJcQGfEY3
#
# Searching for: track:Baggy Jeans artist:NCT U year:2000-2023
# NCT U - Baggy Jeans: 3fR9cyHIKckUDwuy3m5tKn
#
# Searching for: track:Slow Dancing artist:V year:2000-2023
# V - Slow Dancing: 5h1BN75CEh8wdSwE1xrbSe
#
# Searching for: track:That That artist:Psy year:2000-2022
# PSY - That That (prod.&feat. SUGA of BTS): 7GNRUsU3M4XNDDB9xle5Dz
#
# Searching for: track:Future Perfect artist:Enhypen year:2000-2022
# ENHYPEN - Future Perfect (Pass the MIC): 6PRy17C5LiiN7VCLS6IA98
#
# Searching for: track:Warmth artist:Lim Young-woong year:2000-2024
# Lim Young Woong - Warmth: 3vnaEaDxMKdBhqA1t0uAwl
#
# Searching for: track:Super Lady artist:(G)I-dle year:2000-2024
# (G)I-DLE - Super Lady: 105qee9D4ARiRZPZDvGDoH
#
# Searching for: track:XO (Only If You Say Yes) artist:Enhypen year:2000-2024
# ENHYPEN - XO (Only If You Say Yes): 3RkSwrsIadAvqVtMp5yhaB
#
# Searching for: track:Armageddon artist:Aespa year:2000-2024
# aespa - Armageddon: 5eWcGfUCrVFMoYskyfkEPE
#
# Searching for: track:Little Light artist:Doyoung year:2000-2024
# DOYOUNG - Little Light: 1Y5D7m2QtyBdvwvY3gAVNQ
#
# Searching for: track:Body artist:Highlight year:2000-2024
# HIGHLIGHT - BODY: 3jH1IMkaF2I1sDgNDbegq5
#
# Searching for: track:Fate artist:(G)I-dle year:2000-2024
# (G)I-DLE - Fate: 5kt0nWRnFWEeBUyLWSYnkd
#
# Searching for: track:But I artist:Solar year:2000-2024
# Solar - But I: 3kHF06mERCHSLIq1AuSNdZ
#
# Searching for: track:Eve, Psyche & the Bluebeard's Wife artist:Le Sserafim year:2000-2023
# LE SSERAFIM - Eve, Psyche & The Bluebeard’s wife: 4QhnNyKDsAkXPwHkSnuc89
#
# Searching for: track:Love Me Again artist:V year:2000-2023
# V - Love Me Again: 2N0SPREDYqILVEFSsWF5N5
#
# Searching for: track:ETA artist:NewJeans year:2000-2023
# NewJeans - ETA: 56v8WEnGzLByGsDAXDiv4d
#
# Jung Kook - Seven (feat. Latto) (Clean Ver.): 7Hcj0duTWiCSYDtJaztNIt
#
# Searching for: track:To. X artist:Taeyeon year:2000-2023
# TAEYEON - To. X: 2gyCwrOcC6JBoaJ8JGJ7T8
#
# Searching for: track:Smoke artist:Jaehyun year:2000-2024
# JAEHYUN - Smoke: 6kEU60ykxhb0shZMTiPWZL

# %%
## This song is consistently searched incorrectly by the API and I made the decision
## to hard-code the value rather than altering and potentially breaking the query
uniq_song_ids["track:Love artist:Monsta X year:2000-2022"] = "0dLenhMYqqeTlHrZqcXkm6"
uniq_song_ids["track:Love artist:Monsta X year:2000-2022"]
# Out:
# '0dLenhMYqqeTlHrZqcXkm6'

# %%
import os
# Check if the CSV file already exists
csv_file_path = 'all_award_show_winners.csv'
if os.path.exists(csv_file_path):
    print(f'{csv_file_path} already exists. Loading the existing file.")
    all_show_df_winners = pd.read_csv(csv_file_path).drop('Unnamed: 0', axis=1)
else:
    print(f'{csv_file_path} does not exist. Proceeding with scraping and saving data.")
    # Include the scraping and saving logic here
    all_show_df_winners['Song ID'] = all_show_df_winners["Search Query"].map(uniq_song_ids)
    all_show_df_winners.to_csv(csv_file_path)

# %% [markdown]
# ### Extracting Audio Features
#
# At this point, we now have a fairly clean dataset along with the Spotify ID for each track. With this track id, we are going to create another dataset pertaining to the tracks audio features.

# %%
sp.audio_features("3LCwQoTrdQgHsGJE5gGVqx")

# %% [markdown]
# ### **IMPORTANT**: Pivot to MusicXMatch
#
# As of recent, the Spotify API has deprecated the endpoints for the `audio_features` and `audio_analysis` features. Therefore, I spent time to find an alternative which is MusicXMatch. This API has a similar endpoint to Spotify's `audio_features` endpoint and the additional capability of extracting a track's lyrics.
#
# To proceed this pivot to the alternative API, I'm going to import the previous dataframe and begin extracting information for each track.

# %%
df_all_shows = pd.read_csv('all_award_show_winners.csv').drop("Unnamed: 0", axis=1)
df_all_shows.head(5)
# Out:
#   Episode               Date        Artist       Song Points Award Show  \
# 0   1,121    January 9, 2022           Ive     Eleven  8,533   Inkigayo
# 1   1,122   January 16, 2022           Ive     Eleven  6,583   Inkigayo
# 2   1,123   January 23, 2022           Ive     Eleven  5,927   Inkigayo
# 3   1,124   January 30, 2022  Got the Beat  Step Back  5,612   Inkigayo
# 4   1,125  February 20, 2022  Got the Beat  Step Back  7,224   Inkigayo
#
#                                         Search Query                 Song ID
# 0             track:Eleven artist:Ive year:2000-2022  7n2FZQsaLb7ZRfRPfEeIvr
# 1             track:Eleven artist:Ive year:2000-2022  7n2FZQsaLb7ZRfRPfEeIvr
# 2             track:Eleven artist:Ive year:2000-2022  7n2FZQsaLb7ZRfRPfEeIvr
# 3  track:Step Back artist:Got the Beat year:2000-...  3LCwQoTrdQgHsGJE5gGVqx
# 4  track:Step Back artist:Got the Beat year:2000-...  3LCwQoTrdQgHsGJE5gGVqx

# %% [markdown]
# *Minor edit that I missed: Snip the text with parentheses to match the other instances of Future Perfect*

# %%
df_all_shows.loc[df_all_shows.Song == "Future Perfect (Pass the MIC)", "Song"] = "Future Perfect"

# %%
uniq_artists = df_all_shows.Artist.unique().tolist()
uniq_songs = df_all_shows.Song.unique().tolist()
uniq_artists.sort(), uniq_songs.sort()
print(f"Artists: {uniq_artists}\nSongs: {uniq_songs}")
# Out:
# Artists: ['(G)I-dle', 'AB6IX', 'AKMU', 'Aespa', 'Apink', 'Astro', 'Ateez', 'BSS', 'BTS', 'BabyMonster', 'Baekhyun', 'Bibi', 'Big Bang', 'Billlie', 'Blackpink', 'BoyNextDoor', 'BtoB', 'CSR', 'Chungha', 'Cravity', 'DKZ', 'Day6', 'Doyoung', 'Dreamcatcher', 'Enhypen', 'Everglow', 'Evnne', 'Exo', 'Fromis 9', 'G-Dragon', 'Got the Beat', 'H1-Key', 'Han Seung-woo', 'Highlight', 'IU', 'Illit', 'Itzy', 'Ive', 'J-Hope&J. Cole', 'Jaechan', 'Jaehyun', 'Jennie', 'Jihyo', 'Jimin', 'Jin', 'Jisoo', 'Jo Yuri', 'Jung Kook', 'Kai', 'Kang Daniel', 'Kara', 'Kep1er', 'Key', 'Kim Jae-hwan', 'Kim Min-seok', 'Kim Woo Seok', 'Kiss of Life', 'Kwon Eunbi', 'Le Sserafim', 'Lee Chan-won', 'Lee Gi-kwang', 'Lee Young-ji', 'Lim Young-woong', 'Loona', 'Miyeon', 'Monsta X', 'N.SSign', 'NCT 127', 'NCT DoJaeJung', 'NCT Dream', 'NCT U', 'NCT Wish', 'Nayeon', 'NewJeans', 'NiziU', 'Nmixx', 'ONF', 'Oh My Girl', 'Oneus', 'Onew', 'P1Harmony', 'Pentagon', 'Plave', 'Psy', 'QWER', 'Red Velvet', 'Riize', 'Rosé&Bruno Mars', 'SF9', 'STAYC', 'Seventeen', 'Shinee', 'Solar', 'Stray Kids', 'TWS', 'TXT', 'Taemin', 'Taeyang', 'Taeyeon', 'Tempest', 'The Boyz', 'The Wind', 'Tomorrow X Together', 'Treasure', 'TripleS', 'Twice', 'V', 'Vanner', 'Verivery', 'Viviz', 'WSG Wannabe (Gaya-G)', 'WayV', 'Wheein', 'Yena', 'Yeonjun', 'YooA', 'Younha', 'Zerobaseone', 'Zico']
# Songs: ['#menow', '2 Baddies', '3D', 'ABCD', 'After Like', 'Alone', 'Antifragile', 'Apt.', 'Armageddon', 'At That Moment', 'Attention', 'Automatic', 'Ay-Yo', 'BONVOYAGE', 'Baddie', 'Baggy Jeans', 'Baila Conmigo', 'Bam Yang Gang', 'Be There For Me', 'Beatbox', 'Beautiful Liar', 'Beautiful Monster', 'Birthday', 'Bite Me', 'Blessed-Cursed', 'Body', 'Boom Boom Bass', 'Bop Bop!', 'Bouncy (K-Hot Chilli Peppers)', 'Bubble', 'But I', 'But Sometimes', 'Bye My Monster', 'CBZ (Prime Time)', 'Cake', 'Candy', 'Candy Sugar Pop', 'Case 143', 'Chasing That Feeling', 'Cheeky Icy Thang', 'Cheshire', 'Chill Kill', 'Chk Chk Boom', 'Closer Than This', 'Crazy', 'Crazy Form', 'Cream Soda', 'DM', 'Dash', 'Daydream', 'Deja Vu', 'Dilemma', 'Ditto', 'Dive Into', 'Do or Die', "Don't Worry, Be Happy", 'Dragon', 'Drama', 'Drive', 'Drunken Confession', 'ETA', 'Earth, Wind & Fire', 'Easy', 'Either Way', 'Electric Shock', 'Eleven', 'Erase Me', 'Eunoia', "Eve, Psyche & the Bluebeard's Wife", 'Event Horizon', 'Fact Check', 'Fate', 'Fearless', 'Feel My Rhythm', 'Feel the Pop', "Feelin' Like", 'Fighting', 'Flip That', 'Flower', 'Frequency', 'Frequency(Korean Ver.)', 'Fri(end)s', 'Future Perfect', 'Get Loud', 'Ggum', 'Girls', 'Girls Never Die', 'Give Me That', 'Glitch Mode', 'God of Music', 'Good Boy Gone Bad', 'Good So Bad', 'Grain of Sand', 'Groovy', 'Guerrilla', 'Guilty', 'Halazia', 'Happy', 'Hard', 'Heartris', 'Hello', 'Hello, My First Love', 'Hit the Floor', 'Home Sweet Home', 'Hot', 'How Sweet', 'Hype Boy', 'I Am', 'INVU', 'ISTJ', 'Ice on My Teeth', 'If I Say, I Love You', "If I'm S, Can You Be My N?", 'If We Ever Meet Again', 'In Bloom', 'Jikjin', "Killin' It", "Killin' Me Good", 'Kitsch', 'Klaxon', 'Lalalala', 'Lighthouse', 'Like Crazy', 'Lip Gloss', 'Little Light', 'London Boy', 'Loser', 'Love', 'Love 119', 'Love Dive', 'Love Lee', 'Love Me Again', 'Love Me Like This', 'Love Potion', 'Love Shhh!', 'Love Wins All', 'Love or Die', 'Love, Money, Fame', 'Maestro', 'Magnetic', 'Maison', 'Make Me Happy', 'Maniac', 'Mantra', 'Melt Down', 'My Name is Malguem', 'Nectar', 'Nice Guy', 'Nxde', 'O (Circle)', 'OMG', 'On the Street', 'Over the Moon', 'Party Rock', 'Perfect Night', 'Perfume', 'Pineapple Slice', 'Pink Venom', 'Pleasure Shop', 'Plot Twist', 'Pop!', 'Predator', 'Pump Up the Volume', 'Queencard', 'Real Love', 'Rebel Heart', 'Roar', 'Rover', 'Run2U', 'S-Class', 'Sad Song', 'Same Scent', 'See That?', 'Selfish', 'Seoul (Such a Beautiful City)', 'Set Me Free', 'Set Me Free Pt. 2', 'Seven', 'Sheesh', 'Shooting Star', 'Shut Down', 'Slay', 'Slow Dancing', 'Small Girl', 'Smeraldo Garden Marching Band', 'Smiley', 'Smoke', 'Smoothie', 'Sneakers', 'Songbird', 'Sparkling', 'Spicy', 'Spot!', 'Spring Breeze', 'Standing Next to You', 'Stay This Way', 'Steady', 'Step Back', 'Sticky', 'Still Life', 'Strategy', 'Sugar Rush Ride', 'Summer Comes', 'Super', 'Super Lady', 'Super Shy', 'Supernova', 'Supersonic', 'Sweet Venom', 'Switch', 'Take Two', 'Tap Tap', 'Taxi', 'Teddy Bear', 'That That', 'The Astronaut', 'The First Snow', 'The Flash', 'The Song', 'Tipi-tap', 'To. X', 'Tomboy', 'Trigger', 'Ugly', 'Uh-Heung', 'Unforgiven', 'Universe', 'Untouchable', 'Up', 'Up!', 'Upside Down', 'Vibe', 'Vroom Vroom', 'Wa Da Da', 'Walk', 'Walkin on Water', 'Warmth', 'Watch It', 'Way 4 Luv', 'When I Move', "When I'm With You", 'Whiplash', 'Whisper', 'Who', 'Winter Sleep', 'Wish', 'Work', 'XO (Only If You Say Yes)', 'Yet to Come', '_World', '♡Ticon', '풍등', '하늘 여행']

# %%
# If you need to make a high volume of requests, consider using proxies
import json
from musicxmatch_api import MusixMatchAPI
import urllib
api = MusixMatchAPI()

# %%
query_track = set(df_all_shows.Song.str.cat([df_all_shows['Artist'], df_all_shows['Song ID']], sep=" | ").tolist())

# %%
df_all_shows.loc[(df_all_shows.Artist == "NCT 127") & (df_all_shows.Song == "Be There For Me"), "Search Query"].tolist()
# Out:
# ['track:Be There For Me artist:NCT 127 year:2000-2024',
#  'track:Be There For Me artist:NCT 127 year:2000-2024']

# %% [markdown]
# ### Gathering the Track IDs

# %%
import requests
import pandas as pd
import json
from time import sleep

# Load your DataFrame (Assuming it has 'artist' and 'track' columns)
df = pd.read_csv('all_award_show_winners.csv').drop("Unnamed: 0", axis=1) 

BASE_URL = "https://api.musixmatch.com/ws/1.1/"
APP_ID = "cf4d7395cd2d7f5618c4057426e93f26" 

results = []

for _, row in df.iterrows():
    artist = row["Artist"]
    track = row["Song"]
    
    query_url = f"{BASE_URL}matcher.track.get?apikey={APP_ID}&q_artist={artist}&q_track={track}&format=json"
    
    try:
        response = requests.get(query_url)
        data = response.json()
        
        if response.status_code == 200:
            results.append(data)
        else:
            print(f"Error {response.status_code}: {data}")

        sleep(1)  # Prevent hitting rate limits
        
    except Exception as e:
        print(f"Request failed for {artist} - {track}: {e}")

# Save results to a JSON file
with open("musixmatch_results.json", "w") as f:
    json.dump(results, f, indent=4)

print("Finished retrieving track data.")
# Out:
# Finished retrieving track data.

# %%
def extract_unique_artist_tracks(json_filename):
    """
    Reads a JSON file and extracts unique (artist, track) combinations.
    
    :param json_filename: Path to the JSON file containing Musixmatch results
    :return: Set of unique (artist, track) tuples
    """
    unique_tracks = set()

    try:
        # Load JSON data
        with open(json_filename, "r", encoding="utf-8") as file:
            data = json.load(file)

        # Ensure data is a list of dictionaries
        if not isinstance(data, list):
            raise ValueError(f"Expected JSON data to be a list, but got {type(data)}")

        # Extract artist-track pairs
        for entry in data:
            if not isinstance(entry, dict):
                print(f"Skipping invalid entry (not a dict): {entry}")
                continue

            try:
                if entry["message"]["body"] == "":
                    continue
                # Ensure the structure exists before accessing keys
                track_info = entry["message"]["body"]["track"]

                # Extract values
                artist_name = track_info["artist_name"].strip()
                track_name = track_info["track_name"].strip()

                # Debugging: Print extracted data
                print(f"Extracted: Artist = {artist_name}, Track = {track_name}")

                # Add to set if both values exist
                if artist_name and track_name:
                    unique_tracks.add((artist_name, track_name))

            except KeyError as e:
                print(f"Skipping entry due to missing key: {e}")

    except json.JSONDecodeError:
        print("Error: Invalid JSON format in file.")
    except FileNotFoundError:
        print(f"Error: File {json_filename} not found.")
    except Exception as e:
        print(f"Unexpected error: {e}")

    return unique_tracks

json_file = "musixmatch_results.json"
unique_combinations = extract_unique_artist_tracks(json_file)
# Out:
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = GOT the beat, Track = Step Back
# Extracted: Artist = GOT the beat, Track = Step Back
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = Kim MinSeok, Track = DrunKen Confession
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = NCT DREAM, Track = Glitch Mode
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = NCT DREAM, Track = Beatbox
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = NAYEON, Track = POP!
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = NAYEON, Track = POP!
# Extracted: Artist = Small World, Track = Seventeen
# Extracted: Artist = NAYEON, Track = POP!
# Extracted: Artist = ITZY, Track = SNEAKERS
# Extracted: Artist = NewJeans, Track = Attention
# Extracted: Artist = NewJeans, Track = Attention
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = Younha, Track = Event Horizon
# Extracted: Artist = Younha, Track = Event Horizon
# Extracted: Artist = Younha, Track = Event Horizon
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = NewJeans, Track = OMG
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = TOMORROW X TOGETHER, Track = Sugar Rush Ride
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = STAYC, Track = Teddy Bear
# Extracted: Artist = THE BOYZ, Track = ROAR
# Extracted: Artist = NewJeans, Track = OMG
# Extracted: Artist = NewJeans, Track = OMG
# Extracted: Artist = NewJeans, Track = Hype Boy
# Extracted: Artist = IVE, Track = Kitsch
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = SEVENTEEN, Track = Super
# Extracted: Artist = LE SSERAFIM feat. Nile Rodgers, Track = UNFORGIVEN (feat. Nile Rodgers)
# Extracted: Artist = aespa, Track = Spicy
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = SHINee, Track = HARD
# Extracted: Artist = NewJeans, Track = Super Shy
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = NewJeans, Track = Super Shy
# Extracted: Artist = NewJeans, Track = Super Shy
# Extracted: Artist = NewJeans, Track = ETA
# Extracted: Artist = NewJeans, Track = ETA
# Extracted: Artist = AKMU, Track = Love Lee
# Extracted: Artist = AKMU, Track = Love Lee
# Extracted: Artist = AKMU, Track = Love Lee
# Extracted: Artist = IVE, Track = Either Way
# Extracted: Artist = SEVENTEEN, Track = God of Music
# Extracted: Artist = IVE, Track = Baddie
# Extracted: Artist = IVE, Track = Baddie
# Extracted: Artist = aespa, Track = Drama
# Extracted: Artist = IVE, Track = Baddie
# Extracted: Artist = TAEYEON, Track = To. X
# Extracted: Artist = aespa, Track = Drama
# Extracted: Artist = aespa, Track = Drama
# Extracted: Artist = RIIZE, Track = Love 119
# Extracted: Artist = NMIXX, Track = DASH
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = BIBI, Track = Bam Yang Gang
# Extracted: Artist = TWS, Track = plot twist
# Extracted: Artist = (G)I-DLE, Track = Fate
# Extracted: Artist = (G)I-DLE, Track = Fate
# Extracted: Artist = (G)I-DLE, Track = Fate
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ZICO feat. JENNIE, Track = SPOT!
# Extracted: Artist = ZICO feat. JENNIE, Track = SPOT!
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = RIIZE, Track = Boom Boom Bass
# Extracted: Artist = Lee Young Ji feat. D.O., Track = Small girl (feat. D.O.)
# Extracted: Artist = Lee Young Ji feat. D.O., Track = Small girl (feat. D.O.)
# Extracted: Artist = (G)I-DLE, Track = Klaxon
# Extracted: Artist = (G)I-DLE, Track = Klaxon
# Extracted: Artist = (G)I-DLE, Track = Klaxon
# Extracted: Artist = NMIXX, Track = See that?
# Extracted: Artist = ZEROBASEONE, Track = GOOD SO BAD
# Extracted: Artist = BOYNEXTDOOR, Track = Nice Guy
# Extracted: Artist = DAY6, Track = HAPPY
# Extracted: Artist = DAY6, Track = HAPPY
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = aespa, Track = Whiplash
# Extracted: Artist = aespa, Track = Whiplash
# Extracted: Artist = aespa, Track = Whiplash
# Extracted: Artist = G-DRAGON feat. TAEYANG & DAESUNG, Track = HOME SWEET HOME (feat. TAEYANG & DAESUNG)
# Extracted: Artist = G-DRAGON feat. TAEYANG & DAESUNG, Track = HOME SWEET HOME (feat. TAEYANG & DAESUNG)
# Extracted: Artist = G-DRAGON feat. TAEYANG & DAESUNG, Track = HOME SWEET HOME (feat. TAEYANG & DAESUNG)
# Extracted: Artist = BOYNEXTDOOR, Track = IF I SAY, I LOVE YOU
# Extracted: Artist = IVE, Track = REBEL HEART
# Extracted: Artist = Kep1er, Track = WA DA DA
# Extracted: Artist = Kep1er, Track = WA DA DA
# Extracted: Artist = GOT the beat, Track = Step Back
# Extracted: Artist = YENA feat. BIBI, Track = SMILEY (feat. BIBI)
# Extracted: Artist = VIVIZ, Track = BOP BOP!
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = BTOB, Track = The Song
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = NCT DREAM, Track = Glitch Mode
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = Lim Young Woong, Track = If We Ever Meet Again
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = ASTRO, Track = Candy Sugar Pop
# Extracted: Artist = SEVENTEEN, Track = HOT
# Extracted: Artist = NCT DREAM, Track = Beatbox
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = fromis_9, Track = Stay This Way
# Extracted: Artist = NAYEON, Track = POP!
# Extracted: Artist = aespa, Track = Girls
# Extracted: Artist = Small World, Track = Seventeen
# Extracted: Artist = Small World, Track = Seventeen
# Extracted: Artist = ITZY, Track = SNEAKERS
# Extracted: Artist = NewJeans, Track = Attention
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = Stray Kids, Track = CASE 143
# Extracted: Artist = Stray Kids, Track = CASE 143
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = JIN, Track = The Astronaut
# Extracted: Artist = NCT DREAM, Track = Candy
# Extracted: Artist = NewJeans, Track = OMG
# Extracted: Artist = TAEYANG feat. Jimin, Track = VIBE (feat. Jimin of BTS)
# Extracted: Artist = NewJeans, Track = OMG
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = j-hope, Track = on the street (solo version)
# Extracted: Artist = j-hope, Track = on the street (solo version)
# Extracted: Artist = Jimin, Track = Set Me Free, Pt. 2
# Extracted: Artist = Jimin, Track = Like Crazy
# Extracted: Artist = Jimin, Track = Like Crazy
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = SEVENTEEN, Track = Super
# Extracted: Artist = LE SSERAFIM feat. Nile Rodgers, Track = UNFORGIVEN (feat. Nile Rodgers)
# Extracted: Artist = aespa, Track = Spicy
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = ENHYPEN, Track = Bite Me
# Extracted: Artist = Stray Kids, Track = S-Class
# Extracted: Artist = Stray Kids, Track = S-Class
# Extracted: Artist = BTS, Track = Take Two
# Extracted: Artist = BTS, Track = Take Two
# Extracted: Artist = BTS, Track = Take Two
# Extracted: Artist = NewJeans, Track = Super Shy
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = NewJeans, Track = ETA
# Extracted: Artist = NewJeans, Track = ETA
# Extracted: Artist = V, Track = Love Me Again
# Extracted: Artist = V, Track = Love Me Again
# Extracted: Artist = V, Track = Love Me Again
# Extracted: Artist = V, Track = Slow Dancing
# Extracted: Artist = V, Track = Slow Dancing
# Extracted: Artist = V, Track = Slow Dancing
# Extracted: Artist = Jung Kook, Track = 3D (feat. Jack Harlow) (Clean Ver.)
# Extracted: Artist = Jung Kook, Track = 3D (feat. Jack Harlow) (Clean Ver.)
# Extracted: Artist = Jung Kook, Track = 3D (feat. Jack Harlow) (Clean Ver.)
# Extracted: Artist = IVE, Track = Baddie
# Extracted: Artist = SEVENTEEN, Track = God of Music
# Extracted: Artist = Jung Kook, Track = Standing Next to You
# Extracted: Artist = Jung Kook, Track = Standing Next to You
# Extracted: Artist = Jimin, Track = Closer Than This
# Extracted: Artist = RIIZE, Track = Love 119
# Extracted: Artist = NMIXX, Track = DASH
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = (G)I-DLE, Track = Super Lady
# Extracted: Artist = (G)I-DLE, Track = Super Lady
# Extracted: Artist = (G)I-DLE, Track = Super Lady
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = V, Track = FRI(END)S
# Extracted: Artist = V, Track = FRI(END)S
# Extracted: Artist = NCT DREAM, Track = Smoothie
# Extracted: Artist = TOMORROW X TOGETHER, Track = Deja Vu
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = BABYMONSTER, Track = SHEESH
# Extracted: Artist = SEVENTEEN, Track = MAESTRO
# Extracted: Artist = SEVENTEEN, Track = MAESTRO
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = aespa, Track = Armageddon
# Extracted: Artist = aespa, Track = Armageddon
# Extracted: Artist = RIIZE, Track = Boom Boom Bass
# Extracted: Artist = Lee Young Ji feat. D.O., Track = Small girl (feat. D.O.)
# Extracted: Artist = Jimin feat. Loco, Track = Smeraldo Garden Marching Band (feat. Loco)
# Extracted: Artist = Jimin feat. Loco, Track = Smeraldo Garden Marching Band (feat. Loco)
# Extracted: Artist = Stray Kids, Track = Chk Chk Boom
# Extracted: Artist = Jimin, Track = Who
# Extracted: Artist = Jimin, Track = Who
# Extracted: Artist = ZEROBASEONE, Track = GOOD SO BAD
# Extracted: Artist = LE SSERAFIM, Track = CRAZY
# Extracted: Artist = LE SSERAFIM, Track = CRAZY
# Extracted: Artist = LE SSERAFIM, Track = CRAZY
# Extracted: Artist = YEONJUN, Track = GGUM
# Extracted: Artist = QWER, Track = My Name is Malguem
# Extracted: Artist = JENNIE, Track = Mantra
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = Stray Kids, Track = Walkin On Water
# Extracted: Artist = BOYNEXTDOOR, Track = IF I SAY, I LOVE YOU
# Extracted: Artist = IVE, Track = REBEL HEART
# Extracted: Artist = NCT U, Track = Universe (Let's Play Ball)
# Extracted: Artist = Kep1er, Track = WA DA DA
# Extracted: Artist = ENHYPEN, Track = Blessed-Cursed
# Extracted: Artist = IU, Track = Winter Sleep
# Extracted: Artist = PENTAGON, Track = Feelin' Like
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = TREASURE, Track = JIKJIN
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = KIM WOO SEOK, Track = Switch
# Extracted: Artist = Stray Kids, Track = MANIAC
# Extracted: Artist = Red Velvet, Track = Feel My Rhythm
# Extracted: Artist = NCT DREAM, Track = Glitch Mode
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = MONSTA X, Track = LOVE
# Extracted: Artist = LE SSERAFIM, Track = FEARLESS
# Extracted: Artist = TXT, Track = Good Boy Gone Bad (Unpopular Theory Remix)
# Extracted: Artist = ASTRO, Track = Candy Sugar Pop
# Extracted: Artist = NCT DREAM, Track = Beatbox
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = Kep1er, Track = Up!
# Extracted: Artist = fromis_9, Track = Stay This Way
# Extracted: Artist = ENHYPEN, Track = Future Perfect (Pass the MIC)
# Extracted: Artist = ITZY, Track = SNEAKERS
# Extracted: Artist = Small World, Track = Seventeen
# Extracted: Artist = ATEEZ, Track = Guerrilla
# Extracted: Artist = ATEEZ, Track = Guerrilla
# Extracted: Artist = NewJeans, Track = Attention
# Extracted: Artist = THE BOYZ, Track = WHISPER
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = ONEUS, Track = Same Scent
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = NCT 127, Track = 2 Baddies
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = Stray Kids, Track = CASE 143
# Extracted: Artist = Stray Kids, Track = CASE 143
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = LE SSERAFIM, Track = ANTIFRAGILE
# Extracted: Artist = LE SSERAFIM, Track = ANTIFRAGILE
# Extracted: Artist = Highlight, Track = Alone
# Extracted: Artist = VERIVERY, Track = Tap Tap
# Extracted: Artist = ITZY, Track = Cheshire
# Extracted: Artist = KARA, Track = WHEN I MOVE
# Extracted: Artist = Younha, Track = Event Horizon
# Extracted: Artist = NCT DREAM, Track = Candy
# Extracted: Artist = ATEEZ, Track = HALAZIA
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = MONSTA X, Track = Beautiful Liar
# Extracted: Artist = NewJeans, Track = OMG
# Extracted: Artist = NCT 127, Track = Ay-Yo
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = STAYC, Track = Teddy Bear
# Extracted: Artist = THE BOYZ, Track = ROAR
# Extracted: Artist = THE BOYZ, Track = ROAR
# Extracted: Artist = TWICE, Track = SET ME FREE
# Extracted: Artist = KAI, Track = Rover
# Extracted: Artist = Jimin, Track = Like Crazy
# Extracted: Artist = Jimin, Track = Like Crazy
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = NCT DOJAEJUNG, Track = Perfume
# Extracted: Artist = SEVENTEEN, Track = Super
# Extracted: Artist = LE SSERAFIM feat. Nile Rodgers, Track = UNFORGIVEN (feat. Nile Rodgers)
# Extracted: Artist = aespa, Track = Spicy
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = ENHYPEN, Track = Bite Me
# Extracted: Artist = Stray Kids, Track = S-Class
# Extracted: Artist = Stray Kids, Track = S-Class
# Extracted: Artist = ATEEZ, Track = BOUNCY (K-HOT CHILLI PEPPERS)
# Extracted: Artist = ATEEZ, Track = BOUNCY (K-HOT CHILLI PEPPERS)
# Extracted: Artist = SHINee, Track = HARD
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = EXO, Track = Cream Soda
# Extracted: Artist = NCT DREAM, Track = ISTJ
# Extracted: Artist = NCT DREAM, Track = ISTJ
# Extracted: Artist = ITZY, Track = CAKE
# Extracted: Artist = THE BOYZ, Track = LIP GLOSS
# Extracted: Artist = Ji Hyo, Track = Killin' Me Good (English Ver.)
# Extracted: Artist = STAYC, Track = Bubble
# Extracted: Artist = NCT U, Track = Baggy Jeans
# Extracted: Artist = V, Track = Slow Dancing
# Extracted: Artist = V, Track = Slow Dancing
# Extracted: Artist = TEMPEST, Track = Vroom Vroom
# Extracted: Artist = ONEUS, Track = Baila Conmigo
# Extracted: Artist = NCT 127, Track = Fact Check
# Extracted: Artist = VIVA, Track = Chasing That Feeling
# Extracted: Artist = VIVA, Track = Chasing That Feeling
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Stray Kids, Track = LALALALA
# Extracted: Artist = ENHYPEN, Track = Sweet Venom
# Extracted: Artist = THE BOYZ, Track = WATCH IT
# Extracted: Artist = ATEEZ, Track = Crazy Form
# Extracted: Artist = ATEEZ, Track = Crazy Form
# Extracted: Artist = ATEEZ, Track = Crazy Form
# Extracted: Artist = EXO, Track = The First Snow
# Extracted: Artist = NCT 127, Track = Be There For Me
# Extracted: Artist = NCT 127, Track = Be There For Me
# Extracted: Artist = ITZY, Track = UNTOUCHABLE
# Extracted: Artist = NMIXX, Track = DASH
# Extracted: Artist = EVNNE, Track = UGLY
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = P1Harmony, Track = Killin' It
# Extracted: Artist = TWS, Track = plot twist
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = CRAVITY, Track = Love or Die
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = Highlight, Track = BODY
# Extracted: Artist = THE BOYZ, Track = Nectar
# Extracted: Artist = NCT DREAM, Track = Smoothie
# Extracted: Artist = TOMORROW X TOGETHER, Track = Deja Vu
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = BOYNEXTDOOR, Track = Earth, Wind & Fire
# Extracted: Artist = Lee Chanwon, Track = 하늘 여행
# Extracted: Artist = SEVENTEEN, Track = MAESTRO
# Extracted: Artist = SEVENTEEN, Track = MAESTRO
# Extracted: Artist = NewJeans, Track = How Sweet
# Extracted: Artist = ATEEZ, Track = WORK
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = NAYEON, Track = ABCD
# Extracted: Artist = RIIZE, Track = Boom Boom Bass
# Extracted: Artist = TWS, Track = If I’m S, Can You Be My N?
# Extracted: Artist = STAYC, Track = Cheeky Icy Thang
# Extracted: Artist = ENHYPEN, Track = XO (Only If You Say Yes)
# Extracted: Artist = Stray Kids, Track = Chk Chk Boom
# Extracted: Artist = NCT 127, Track = Walk
# Extracted: Artist = NCT 127, Track = Walk
# Extracted: Artist = Stray Kids, Track = Chk Chk Boom
# Extracted: Artist = NMIXX, Track = See that?
# Extracted: Artist = ZEROBASEONE, Track = GOOD SO BAD
# Extracted: Artist = BAEKHYUN, Track = Pineapple Slice
# Extracted: Artist = BOYNEXTDOOR, Track = Nice Guy
# Extracted: Artist = P1Harmony, Track = SAD SONG
# Extracted: Artist = NCT WISH, Track = Steady
# Extracted: Artist = VANNER, Track = Automatic
# Extracted: Artist = The Wind, Track = Hello, My First Love
# Extracted: Artist = SEVENTEEN, Track = LOVE, MONEY, FAME (TAK Remix)
# Extracted: Artist = aespa, Track = Whiplash
# Extracted: Artist = THE BOYZ, Track = TRIGGER
# Extracted: Artist = TOMORROW X TOGETHER, Track = Over The Moon
# Extracted: Artist = NCT DREAM, Track = When I'm With You
# Extracted: Artist = ATEEZ, Track = Ice On My Teeth
# Extracted: Artist = WayV, Track = FREQUENCY (超频率)
# Extracted: Artist = TWICE, Track = Strategy
# Extracted: Artist = Stray Kids, Track = Walkin On Water
# Extracted: Artist = Stray Kids, Track = Walkin On Water
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = n.SSign, Track = Love Potion (白日夢)
# Extracted: Artist = BSS, Track = CBZ (Prime time)
# Extracted: Artist = IVE, Track = REBEL HEART
# Extracted: Artist = ENHYPEN, Track = Blessed-Cursed
# Extracted: Artist = VIVIZ, Track = BOP BOP!
# Extracted: Artist = TREASURE, Track = JIKJIN
# Extracted: Artist = BTOB, Track = The Song
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = Stray Kids, Track = MANIAC
# Extracted: Artist = NCT DREAM, Track = Glitch Mode
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = Dreamcatcher, Track = MAISON
# Extracted: Artist = MONSTA X, Track = LOVE
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = ASTRO, Track = Candy Sugar Pop
# Extracted: Artist = LE SSERAFIM, Track = FEARLESS
# Extracted: Artist = NCT DREAM, Track = Beatbox
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = LOONA, Track = Flip That
# Extracted: Artist = fromis_9, Track = Stay This Way
# Extracted: Artist = ENHYPEN, Track = Future Perfect (Pass the MIC)
# Extracted: Artist = aespa, Track = Girls
# Extracted: Artist = Small World, Track = Seventeen
# Extracted: Artist = ATEEZ, Track = Guerrilla
# Extracted: Artist = ATEEZ, Track = Guerrilla
# Extracted: Artist = BLACKPINK, Track = Pink Venom
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = ONEUS, Track = Same Scent
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = Stray Kids, Track = CASE 143
# Extracted: Artist = Stray Kids, Track = CASE 143
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = Highlight, Track = Alone
# Extracted: Artist = VERIVERY, Track = Tap Tap
# Extracted: Artist = TEMPEST, Track = Dragon
# Extracted: Artist = Red Velvet, Track = Birthday
# Extracted: Artist = Red Velvet, Track = Birthday
# Extracted: Artist = NCT 127, Track = Ay-Yo
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = STAYC, Track = Teddy Bear
# Extracted: Artist = THE BOYZ, Track = ROAR
# Extracted: Artist = STAYC, Track = Teddy Bear
# Extracted: Artist = TWICE, Track = SET ME FREE
# Extracted: Artist = NMIXX, Track = Love Me Like This
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = SEVENTEEN, Track = Super
# Extracted: Artist = LE SSERAFIM feat. Nile Rodgers, Track = UNFORGIVEN (feat. Nile Rodgers)
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = Dreamcatcher, Track = BONVOYAGE
# Extracted: Artist = Stray Kids, Track = S-Class
# Extracted: Artist = Stray Kids, Track = S-Class
# Extracted: Artist = ATEEZ, Track = BOUNCY (K-HOT CHILLI PEPPERS)
# Extracted: Artist = Lim Young Woong, Track = Grain of Sand
# Extracted: Artist = SHINee, Track = HARD
# Extracted: Artist = SHINee, Track = HARD
# Extracted: Artist = ZEROBASEONE, Track = In Bloom
# Extracted: Artist = NCT DREAM, Track = ISTJ
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = NewJeans, Track = Super Shy
# Extracted: Artist = EVERGLOW, Track = SLAY
# Extracted: Artist = NCT U, Track = Baggy Jeans
# Extracted: Artist = BOYNEXTDOOR, Track = But Sometimes
# Extracted: Artist = V, Track = Slow Dancing
# Extracted: Artist = TEMPEST, Track = Vroom Vroom
# Extracted: Artist = NCT 127, Track = Fact Check
# Extracted: Artist = NCT 127, Track = Fact Check
# Extracted: Artist = IVE, Track = Baddie
# Extracted: Artist = SEVENTEEN, Track = God of Music
# Extracted: Artist = NiziU, Track = HEARTRIS
# Extracted: Artist = Stray Kids, Track = LALALALA
# Extracted: Artist = ATEEZ, Track = Crazy Form
# Extracted: Artist = EVNNE, Track = UGLY
# Extracted: Artist = (G)I-DLE, Track = Super Lady
# Extracted: Artist = TWS, Track = plot twist
# Extracted: Artist = TWS, Track = plot twist
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = PLAVE, Track = WAY 4 LUV
# Extracted: Artist = NCT WISH, Track = WISH (Korean Ver.)
# Extracted: Artist = TEMPEST, Track = LIGHTHOUSE
# Extracted: Artist = THE BOYZ, Track = Nectar
# Extracted: Artist = NCT DREAM, Track = Smoothie
# Extracted: Artist = TOMORROW X TOGETHER, Track = Deja Vu
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = BOYNEXTDOOR, Track = Earth, Wind & Fire
# Extracted: Artist = DOYOUNG, Track = Little Light
# Extracted: Artist = SEVENTEEN, Track = MAESTRO
# Extracted: Artist = ZEROBASEONE, Track = Feel the POP
# Extracted: Artist = NewJeans, Track = How Sweet
# Extracted: Artist = aespa, Track = Armageddon
# Extracted: Artist = Kep1er, Track = Shooting Star
# Extracted: Artist = NAYEON, Track = ABCD
# Extracted: Artist = RIIZE, Track = Boom Boom Bass
# Extracted: Artist = TWS, Track = If I’m S, Can You Be My N?
# Extracted: Artist = NCT WISH, Track = Songbird - Japanese Ver.
# Extracted: Artist = KISS OF LIFE, Track = Sticky
# Extracted: Artist = Stray Kids, Track = Chk Chk Boom
# Extracted: Artist = Stray Kids, Track = Chk Chk Boom
# Extracted: Artist = Stray Kids, Track = Chk Chk Boom
# Extracted: Artist = ZEROBASEONE, Track = GOOD SO BAD
# Extracted: Artist = LE SSERAFIM, Track = CRAZY
# Extracted: Artist = P1Harmony, Track = SAD SONG
# Extracted: Artist = KANG DANIEL, Track = Electric Shock
# Extracted: Artist = QWER, Track = My Name is Malguem
# Extracted: Artist = SEVENTEEN, Track = LOVE, MONEY, FAME (TAK Remix)
# Extracted: Artist = aespa, Track = Whiplash
# Extracted: Artist = THE BOYZ, Track = TRIGGER
# Extracted: Artist = TOMORROW X TOGETHER, Track = Over The Moon
# Extracted: Artist = NCT DREAM, Track = When I'm With You
# Extracted: Artist = WayV, Track = FREQUENCY - Korean Version
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = IVE, Track = ELEVEN
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = TAEYEON, Track = INVU
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = NCT DREAM, Track = Glitch Mode
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = BIGBANG, Track = Still Life
# Extracted: Artist = Lim Young Woong, Track = If We Ever Meet Again
# Extracted: Artist = PSY feat. SUGA, Track = That That (prod.&feat. SUGA of BTS)
# Extracted: Artist = KANG DANIEL, Track = Upside Down
# Extracted: Artist = NCT DREAM, Track = Beatbox
# Extracted: Artist = BTS, Track = Yet To Come
# Extracted: Artist = Lim Young Woong, Track = If We Ever Meet Again
# Extracted: Artist = fromis_9, Track = Stay This Way
# Extracted: Artist = NAYEON, Track = POP!
# Extracted: Artist = WSG WANNBE (Gaya-G), Track = At That Moment
# Extracted: Artist = WSG WANNBE (Gaya-G), Track = At That Moment
# Extracted: Artist = NewJeans, Track = Attention
# Extracted: Artist = THE BOYZ, Track = WHISPER
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = NCT 127, Track = 2 Baddies
# Extracted: Artist = BLACKPINK, Track = Shut Down
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = Lim Young Woong, Track = London Boy
# Extracted: Artist = LE SSERAFIM, Track = ANTIFRAGILE
# Extracted: Artist = LE SSERAFIM, Track = ANTIFRAGILE
# Extracted: Artist = LE SSERAFIM, Track = ANTIFRAGILE
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = NewJeans, Track = Ditto
# Extracted: Artist = NCT 127, Track = Ay-Yo
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = BSS feat. Lee Young Ji, Track = Fighting (Feat. Lee Young Ji)
# Extracted: Artist = THE BOYZ, Track = ROAR
# Extracted: Artist = STAYC, Track = Teddy Bear
# Extracted: Artist = ONEW, Track = O (Circle)
# Extracted: Artist = KAI, Track = Rover
# Extracted: Artist = IVE, Track = Kitsch
# Extracted: Artist = JISOO, Track = FLOWER
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = NCT DOJAEJUNG, Track = Perfume
# Extracted: Artist = SEVENTEEN, Track = Super
# Extracted: Artist = LE SSERAFIM feat. Nile Rodgers, Track = UNFORGIVEN (feat. Nile Rodgers)
# Extracted: Artist = aespa, Track = Spicy
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = Lim Young Woong, Track = Grain of Sand
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = SHINee, Track = HARD
# Extracted: Artist = Lim Young Woong, Track = Grain of Sand
# Extracted: Artist = NewJeans, Track = Super Shy
# Extracted: Artist = NCT DREAM, Track = ISTJ
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = Jung Kook feat. Latto, Track = Seven (feat. Latto) (Clean Ver.)
# Extracted: Artist = AKMU, Track = Love Lee
# Extracted: Artist = AKMU, Track = Love Lee
# Extracted: Artist = NCT 127, Track = Fact Check
# Extracted: Artist = Lim Young Woong, Track = Do or Die
# Extracted: Artist = Lim Young Woong, Track = Do or Die
# Extracted: Artist = SEVENTEEN, Track = God of Music
# Extracted: Artist = Taemin, Track = Guilty
# Extracted: Artist = Stray Kids, Track = LALALALA
# Extracted: Artist = Red Velvet, Track = Chill Kill
# Extracted: Artist = THE BOYZ, Track = WATCH IT
# Extracted: Artist = LE SSERAFIM, Track = Perfect Night
# Extracted: Artist = LE SSERAFIM, Track = Perfect Night
# Extracted: Artist = TAEYEON, Track = To. X
# Extracted: Artist = TAEYEON, Track = To. X
# Extracted: Artist = TAEYEON, Track = To. X
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = IU, Track = Love wins all
# Extracted: Artist = LE SSERAFIM, Track = EASY
# Extracted: Artist = PLAVE, Track = WAY 4 LUV
# Extracted: Artist = BIBI, Track = Bam Yang Gang
# Extracted: Artist = THE BOYZ, Track = Nectar
# Extracted: Artist = NCT DREAM, Track = Smoothie
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = Lee Chanwon, Track = 하늘 여행
# Extracted: Artist = SEVENTEEN, Track = MAESTRO
# Extracted: Artist = Lim Young Woong, Track = Warmth
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = aespa, Track = Supernova
# Extracted: Artist = NewJeans, Track = How Sweet
# Extracted: Artist = NewJeans, Track = How Sweet
# Extracted: Artist = NewJeans, Track = How Sweet
# Extracted: Artist = Lee Young Ji feat. D.O., Track = Small girl (feat. D.O.)
# Extracted: Artist = Lee Young Ji feat. D.O., Track = Small girl (feat. D.O.)
# Extracted: Artist = Lee Young Ji feat. D.O., Track = Small girl (feat. D.O.)
# Extracted: Artist = NCT 127, Track = Walk
# Extracted: Artist = PLAVE, Track = Pump Up The Volume!
# Extracted: Artist = JAEHYUN, Track = Smoke
# Extracted: Artist = DAY6, Track = Melt Down
# Extracted: Artist = DAY6, Track = Melt Down
# Extracted: Artist = DAY6, Track = Melt Down
# Extracted: Artist = Key, Track = Pleasure Shop
# Extracted: Artist = QWER, Track = My Name is Malguem
# Extracted: Artist = aespa, Track = UP (KARINA Solo)
# Extracted: Artist = SEVENTEEN, Track = LOVE, MONEY, FAME (TAK Remix)
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = ROSÉ, Track = APT.
# Extracted: Artist = NCT DREAM, Track = When I'm With You
# Extracted: Artist = aespa, Track = Whiplash
# Extracted: Artist = G-DRAGON feat. TAEYANG & DAESUNG, Track = HOME SWEET HOME (feat. TAEYANG & DAESUNG)
# Extracted: Artist = G-DRAGON feat. TAEYANG & DAESUNG, Track = HOME SWEET HOME (feat. TAEYANG & DAESUNG)
# Extracted: Artist = G-DRAGON feat. TAEYANG & DAESUNG, Track = HOME SWEET HOME (feat. TAEYANG & DAESUNG)
# Extracted: Artist = IVE, Track = REBEL HEART
# Extracted: Artist = Apink, Track = Dilemma
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = STAYC, Track = RUN2U
# Extracted: Artist = (G)I-DLE, Track = TOMBOY
# Extracted: Artist = Highlight, Track = DAYDREAM
# Extracted: Artist = OH MY GIRL, Track = Real Love
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = IVE, Track = LOVE DIVE
# Extracted: Artist = Dreamcatcher, Track = MAISON
# Extracted: Artist = MIYEON, Track = Drive
# Extracted: Artist = LE SSERAFIM, Track = FEARLESS
# Extracted: Artist = LE SSERAFIM, Track = FEARLESS
# Extracted: Artist = ASTRO, Track = Candy Sugar Pop
# Extracted: Artist = JO YURI, Track = Love Shhh!
# Extracted: Artist = LOONA, Track = Flip That
# Extracted: Artist = fromis_9, Track = Stay This Way
# Extracted: Artist = ENHYPEN, Track = Future Perfect (Pass the MIC)
# Extracted: Artist = CHUNG HA, Track = Sparkling
# Extracted: Artist = STAYC, Track = BEAUTIFUL MONSTER
# Extracted: Artist = ATEEZ, Track = Guerrilla
# Extracted: Artist = ATEEZ, Track = Guerrilla
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = IVE, Track = After LIKE
# Extracted: Artist = ONEUS, Track = Same Scent
# Extracted: Artist = ONEUS, Track = Same Scent
# Extracted: Artist = CRAVITY, Track = PARTY ROCK
# Extracted: Artist = DONGKIZ, Track = Uh-Heung
# Extracted: Artist = (G)I-DLE, Track = Nxde
# Extracted: Artist = Highlight, Track = Alone
# Extracted: Artist = STAYC, Track = Teddy Bear
# Extracted: Artist = Lee Chanwon, Track = 풍등
# Extracted: Artist = CRAVITY, Track = Groovy
# Extracted: Artist = Kim Jae Hwan, Track = Spring Breeze
# Extracted: Artist = Billlie, Track = EUNOIA
# Extracted: Artist = IVE, Track = I AM
# Extracted: Artist = LE SSERAFIM feat. Nile Rodgers, Track = UNFORGIVEN (feat. Nile Rodgers)
# Extracted: Artist = ONEUS, Track = ERASE ME
# Extracted: Artist = (G)I-DLE, Track = Queencard
# Extracted: Artist = Dreamcatcher, Track = BONVOYAGE
# Extracted: Artist = AB6IX, Track = LOSER
# Extracted: Artist = ATEEZ, Track = BOUNCY (K-HOT CHILLI PEPPERS)
# Extracted: Artist = ATEEZ, Track = BOUNCY (K-HOT CHILLI PEPPERS)
# Extracted: Artist = HAN SEUNG WOO, Track = Dive Into
# Extracted: Artist = ZEROBASEONE, Track = In Bloom
# Extracted: Artist = ZEROBASEONE, Track = In Bloom
# Extracted: Artist = OH MY GIRL, Track = Summer Comes
# Extracted: Artist = KWON EUN BI, Track = The Flash
# Extracted: Artist = JO YURI, Track = TAXI
# Extracted: Artist = STAYC, Track = Bubble
# Extracted: Artist = H1-KEY, Track = SEOUL (Such a Beautiful City)
# Extracted: Artist = BOYNEXTDOOR, Track = But Sometimes
# Extracted: Artist = JAECHAN, Track = Hello
# Extracted: Artist = ONEUS, Track = Baila Conmigo
# Extracted: Artist = TWS, Track = plot twist
# Extracted: Artist = CRAVITY, Track = Love or Die
# Extracted: Artist = NCT WISH, Track = WISH (Korean Ver.)
# Extracted: Artist = Highlight, Track = BODY
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ILLIT, Track = Magnetic
# Extracted: Artist = ONF, Track = Bye My Monster
# Extracted: Artist = BOYNEXTDOOR, Track = Earth, Wind & Fire
# Extracted: Artist = Solar, Track = But I
# Extracted: Artist = tripleS, Track = Girls Never Die
# Extracted: Artist = ZEROBASEONE, Track = Feel the POP
# Extracted: Artist = ZEROBASEONE, Track = Feel the POP
# Extracted: Artist = ATEEZ, Track = WORK
# Extracted: Artist = WayV, Track = Give Me That
# Extracted: Artist = RIIZE, Track = Boom Boom Bass
# Extracted: Artist = TWS, Track = If I’m S, Can You Be My N?
# Extracted: Artist = KISS OF LIFE, Track = Sticky
# Extracted: Artist = SF9, Track = Don't Worry, Be Happy (feat. JAE YOON)
# Extracted: Artist = ZEROBASEONE, Track = GOOD SO BAD
# Extracted: Artist = P1Harmony, Track = SAD SONG
# Extracted: Artist = KISS OF LIFE, Track = Get Loud
# Extracted: Artist = tripleS, Track = Hit the Floor
# Extracted: Artist = Kep1er, Track = TIPI-TAP
# Extracted: Artist = WayV, Track = FREQUENCY (超频率)

# %%
def extract_all_artist_tracks(json_filename):
    """
    Reads a JSON file and extracts all of the song ids to merge it with our original data frame.
    
    :param json_filename: Path to the JSON file containing Musixmatch results
    :return: Set of unique (artist, track) tuples
    """
    tracks = list()

    try:
        # Load JSON data
        with open(json_filename, "r", encoding="utf-8") as file:
            data = json.load(file)

        # Ensure data is a list of dictionaries
        if not isinstance(data, list):
            raise ValueError(f"Expected JSON data to be a list, but got {type(data)}")

        # Extract artist-track pairs
        for entry in data:
            if not isinstance(entry, dict):
                print(f"Skipping invalid entry (not a dict): {entry}")
                continue

            try:
                if entry["message"]["body"] == "":
                    tracks.append("Not Found")
                # Ensure the structure exists before accessing keys
                track_info = entry["message"]["body"]["track"]

                # Extract values
                track_id = track_info["track_id"].strip()
                track_name = track_info["track_name"].strip()

                # Debugging: Print extracted data
                print(f"Extracted: Artist = {artist_name}, Track = {track_name}")

                # Add to set if both values exist
                if artist_name and track_name:
                    unique_tracks.add((artist_name, track_name))

            except KeyError as e:
                print(f"Skipping entry due to missing key: {e}")

    except json.JSONDecodeError:
        print("Error: Invalid JSON format in file.")
    except FileNotFoundError:
        print(f"Error: File {json_filename} not found.")
    except Exception as e:
        print(f"Unexpected error: {e}")

    return unique_tracks

json_file = "musixmatch_results.json"
unique_combinations = extract_unique_artist_tracks(json_file)

# %%
unique_df_tracks = set(zip(df["Artist"], df["Song"]))

# %%
def normalize_and_print_side_by_side(list1, list2, header1="DataFrame Tracks", header2="JSON Tracks", spacing=40):
    """
    Prints two lists side by side with aligned formatting after normalizing (lowercasing) and sorting.
    
    :param list1: First list (e.g., DataFrame unique tracks)
    :param list2: Second list (e.g., JSON unique tracks)
    :param header1: Title for first column
    :param header2: Title for second column
    :param spacing: Width allocated for each column
    """
    # Normalize to lowercase and sort
    list1 = sorted({(artist.lower(), track.lower()) for artist, track in list1})
    list2 = sorted({(artist.lower(), track.lower()) for artist, track in list2})

    # Print headers
    print(f"{header1.ljust(spacing)} {header2}")
    print("=" * (spacing * 2))

    # Print items side by side
    for item1, item2 in zip(list1, list2):
        print(f"{str(item1).ljust(spacing)} {str(item2)}")

    # Handle cases where lists have different lengths
    longer_list = list1 if len(list1) > len(list2) else list2
    extra_items = longer_list[len(list1):] if len(list1) < len(list2) else longer_list[len(list2):]

    for item in extra_items:
        print(f"{str(item).ljust(spacing)} -") if list1 is longer_list else print(f"{'-'.ljust(spacing)} {str(item)}")

# Example usage
normalize_and_print_side_by_side(unique_df_tracks, unique_combinations)
# Out:
# DataFrame Tracks                         JSON Tracks
# ================================================================================
# ('(g)i-dle', 'fate')                     ('(g)i-dle', 'fate')
# ('(g)i-dle', 'klaxon')                   ('(g)i-dle', 'klaxon')
# ('(g)i-dle', 'nxde')                     ('(g)i-dle', 'nxde')
# ('(g)i-dle', 'queencard')                ('(g)i-dle', 'queencard')
# ('(g)i-dle', 'super lady')               ('(g)i-dle', 'super lady')
# ('(g)i-dle', 'tomboy')                   ('(g)i-dle', 'tomboy')
# ('ab6ix', 'loser')                       ('ab6ix', 'loser')
# ('aespa', 'armageddon')                  ('aespa', 'armageddon')
# ('aespa', 'drama')                       ('aespa', 'drama')
# ('aespa', 'girls')                       ('aespa', 'girls')
# ('aespa', 'spicy')                       ('aespa', 'spicy')
# ('aespa', 'supernova')                   ('aespa', 'supernova')
# ('aespa', 'up')                          ('aespa', 'up (karina solo)')
# ('aespa', 'whiplash')                    ('aespa', 'whiplash')
# ('akmu', 'love lee')                     ('akmu', 'love lee')
# ('apink', 'dilemma')                     ('apink', 'dilemma')
# ('astro', 'candy sugar pop')             ('astro', 'candy sugar pop')
# ('ateez', 'bouncy (k-hot chilli peppers)') ('ateez', 'bouncy (k-hot chilli peppers)')
# ('ateez', 'crazy form')                  ('ateez', 'crazy form')
# ('ateez', 'guerrilla')                   ('ateez', 'guerrilla')
# ('ateez', 'halazia')                     ('ateez', 'halazia')
# ('ateez', 'ice on my teeth')             ('ateez', 'ice on my teeth')
# ('ateez', 'work')                        ('ateez', 'work')
# ('babymonster', 'sheesh')                ('babymonster', 'sheesh')
# ('baekhyun', 'pineapple slice')          ('baekhyun', 'pineapple slice')
# ('bibi', 'bam yang gang')                ('bibi', 'bam yang gang')
# ('big bang', 'still life')               ('bigbang', 'still life')
# ('billlie', 'eunoia')                    ('billlie', 'eunoia')
# ('blackpink', 'pink venom')              ('blackpink', 'pink venom')
# ('blackpink', 'shut down')               ('blackpink', 'shut down')
# ('boynextdoor', 'but sometimes')         ('boynextdoor', 'but sometimes')
# ('boynextdoor', 'earth, wind & fire')    ('boynextdoor', 'earth, wind & fire')
# ('boynextdoor', 'if i say, i love you')  ('boynextdoor', 'if i say, i love you')
# ('boynextdoor', 'nice guy')              ('boynextdoor', 'nice guy')
# ('bss', 'cbz (prime time)')              ('bss', 'cbz (prime time)')
# ('bss', 'fighting')                      ('bss feat. lee young ji', 'fighting (feat. lee young ji)')
# ('btob', 'the song')                     ('btob', 'the song')
# ('bts', 'take two')                      ('bts', 'take two')
# ('bts', 'yet to come')                   ('bts', 'yet to come')
# ('chungha', 'sparkling')                 ('chung ha', 'sparkling')
# ('cravity', 'groovy')                    ('cravity', 'groovy')
# ('cravity', 'love or die')               ('cravity', 'love or die')
# ('cravity', 'party rock')                ('cravity', 'party rock')
# ('csr', '♡ticon')                        ('day6', 'happy')
# ('day6', 'happy')                        ('day6', 'melt down')
# ('day6', 'melt down')                    ('dongkiz', 'uh-heung')
# ('dkz', 'uh-heung')                      ('doyoung', 'little light')
# ('doyoung', 'little light')              ('dreamcatcher', 'bonvoyage')
# ('dreamcatcher', 'bonvoyage')            ('dreamcatcher', 'maison')
# ('dreamcatcher', 'maison')               ('enhypen', 'bite me')
# ('enhypen', 'bite me')                   ('enhypen', 'blessed-cursed')
# ('enhypen', 'blessed-cursed')            ('enhypen', 'future perfect (pass the mic)')
# ('enhypen', 'future perfect')            ('enhypen', 'sweet venom')
# ('enhypen', 'future perfect (pass the mic)') ('enhypen', 'xo (only if you say yes)')
# ('enhypen', 'sweet venom')               ('everglow', 'slay')
# ('enhypen', 'xo (only if you say yes)')  ('evnne', 'ugly')
# ('everglow', 'slay')                     ('exo', 'cream soda')
# ('evnne', 'ugly')                        ('exo', 'the first snow')
# ('exo', 'cream soda')                    ('fromis_9', 'stay this way')
# ('exo', 'the first snow')                ('g-dragon feat. taeyang & daesung', 'home sweet home (feat. taeyang & daesung)')
# ('fromis 9', '#menow')                   ('got the beat', 'step back')
# ('fromis 9', 'dm')                       ('h1-key', 'seoul (such a beautiful city)')
# ('fromis 9', 'stay this way')            ('han seung woo', 'dive into')
# ('fromis 9', 'supersonic')               ('highlight', 'alone')
# ('g-dragon', 'home sweet home')          ('highlight', 'body')
# ('got the beat', 'step back')            ('highlight', 'daydream')
# ('h1-key', 'seoul (such a beautiful city)') ('illit', 'magnetic')
# ('han seung-woo', 'dive into')           ('itzy', 'cake')
# ('highlight', 'alone')                   ('itzy', 'cheshire')
# ('highlight', 'body')                    ('itzy', 'sneakers')
# ('highlight', 'daydream')                ('itzy', 'untouchable')
# ('illit', 'magnetic')                    ('iu', 'love wins all')
# ('itzy', 'cake')                         ('iu', 'winter sleep')
# ('itzy', 'cheshire')                     ('ive', 'after like')
# ('itzy', 'sneakers')                     ('ive', 'baddie')
# ('itzy', 'untouchable')                  ('ive', 'either way')
# ('iu', 'love wins all')                  ('ive', 'eleven')
# ('iu', 'winter sleep')                   ('ive', 'i am')
# ('ive', 'after like')                    ('ive', 'kitsch')
# ('ive', 'baddie')                        ('ive', 'love dive')
# ('ive', 'either way')                    ('ive', 'rebel heart')
# ('ive', 'eleven')                        ('j-hope', 'on the street (solo version)')
# ('ive', 'i am')                          ('jaechan', 'hello')
# ('ive', 'kitsch')                        ('jaehyun', 'smoke')
# ('ive', 'love dive')                     ('jennie', 'mantra')
# ('ive', 'rebel heart')                   ('ji hyo', "killin' me good (english ver.)")
# ('j-hope&j. cole', 'on the street')      ('jimin', 'closer than this')
# ('jaechan', 'hello')                     ('jimin', 'like crazy')
# ('jaehyun', 'smoke')                     ('jimin', 'set me free, pt. 2')
# ('jennie', 'mantra')                     ('jimin', 'who')
# ('jihyo', "killin' me good")             ('jimin feat. loco', 'smeraldo garden marching band (feat. loco)')
# ('jimin', 'closer than this')            ('jin', 'the astronaut')
# ('jimin', 'like crazy')                  ('jisoo', 'flower')
# ('jimin', 'set me free pt. 2')           ('jo yuri', 'love shhh!')
# ('jimin', 'smeraldo garden marching band') ('jo yuri', 'taxi')
# ('jimin', 'who')                         ('jung kook', '3d (feat. jack harlow) (clean ver.)')
# ('jin', 'the astronaut')                 ('jung kook', 'standing next to you')
# ('jisoo', 'flower')                      ('jung kook feat. latto', 'seven (feat. latto) (clean ver.)')
# ('jo yuri', 'love shhh!')                ('kai', 'rover')
# ('jo yuri', 'taxi')                      ('kang daniel', 'electric shock')
# ('jung kook', '3d')                      ('kang daniel', 'upside down')
# ('jung kook', 'seven')                   ('kara', 'when i move')
# ('jung kook', 'standing next to you')    ('kep1er', 'shooting star')
# ('kai', 'rover')                         ('kep1er', 'tipi-tap')
# ('kang daniel', 'electric shock')        ('kep1er', 'up!')
# ('kang daniel', 'upside down')           ('kep1er', 'wa da da')
# ('kara', 'when i move')                  ('key', 'pleasure shop')
# ('kep1er', 'shooting star')              ('kim jae hwan', 'spring breeze')
# ('kep1er', 'tipi-tap')                   ('kim minseok', 'drunken confession')
# ('kep1er', 'up!')                        ('kim woo seok', 'switch')
# ('kep1er', 'wa da da')                   ('kiss of life', 'get loud')
# ('key', 'pleasure shop')                 ('kiss of life', 'sticky')
# ('kim jae-hwan', 'spring breeze')        ('kwon eun bi', 'the flash')
# ('kim min-seok', 'drunken confession')   ('le sserafim', 'antifragile')
# ('kim woo seok', 'switch')               ('le sserafim', 'crazy')
# ('kiss of life', 'get loud')             ('le sserafim', 'easy')
# ('kiss of life', 'sticky')               ('le sserafim', 'fearless')
# ('kwon eunbi', 'the flash')              ('le sserafim', 'perfect night')
# ('le sserafim', 'antifragile')           ('le sserafim feat. nile rodgers', 'unforgiven (feat. nile rodgers)')
# ('le sserafim', 'crazy')                 ('lee chanwon', '풍등')
# ('le sserafim', 'easy')                  ('lee chanwon', '하늘 여행')
# ('le sserafim', "eve, psyche & the bluebeard's wife") ('lee young ji feat. d.o.', 'small girl (feat. d.o.)')
# ('le sserafim', 'fearless')              ('lim young woong', 'do or die')
# ('le sserafim', 'perfect night')         ('lim young woong', 'grain of sand')
# ('le sserafim', 'unforgiven')            ('lim young woong', 'if we ever meet again')
# ('lee chan-won', '풍등')                   ('lim young woong', 'london boy')
# ('lee chan-won', '하늘 여행')                ('lim young woong', 'warmth')
# ('lee gi-kwang', 'predator')             ('loona', 'flip that')
# ('lee young-ji', 'small girl')           ('miyeon', 'drive')
# ('lim young-woong', 'do or die')         ('monsta x', 'beautiful liar')
# ('lim young-woong', 'grain of sand')     ('monsta x', 'love')
# ('lim young-woong', 'if we ever meet again') ('n.ssign', 'love potion (白日夢)')
# ('lim young-woong', 'london boy')        ('nayeon', 'abcd')
# ('lim young-woong', 'warmth')            ('nayeon', 'pop!')
# ('loona', 'flip that')                   ('nct 127', '2 baddies')
# ('miyeon', 'drive')                      ('nct 127', 'ay-yo')
# ('monsta x', 'beautiful liar')           ('nct 127', 'be there for me')
# ('monsta x', 'love')                     ('nct 127', 'fact check')
# ('n.ssign', 'love potion')               ('nct 127', 'walk')
# ('nayeon', 'abcd')                       ('nct dojaejung', 'perfume')
# ('nayeon', 'pop!')                       ('nct dream', 'beatbox')
# ('nct 127', '2 baddies')                 ('nct dream', 'candy')
# ('nct 127', 'ay-yo')                     ('nct dream', 'glitch mode')
# ('nct 127', 'be there for me')           ('nct dream', 'istj')
# ('nct 127', 'fact check')                ('nct dream', 'smoothie')
# ('nct 127', 'walk')                      ('nct dream', "when i'm with you")
# ('nct dojaejung', 'perfume')             ('nct u', 'baggy jeans')
# ('nct dream', 'beatbox')                 ('nct u', "universe (let's play ball)")
# ('nct dream', 'candy')                   ('nct wish', 'songbird - japanese ver.')
# ('nct dream', 'glitch mode')             ('nct wish', 'steady')
# ('nct dream', 'istj')                    ('nct wish', 'wish (korean ver.)')
# ('nct dream', 'smoothie')                ('newjeans', 'attention')
# ('nct dream', "when i'm with you")       ('newjeans', 'ditto')
# ('nct u', 'baggy jeans')                 ('newjeans', 'eta')
# ('nct u', 'universe')                    ('newjeans', 'how sweet')
# ('nct wish', 'songbird')                 ('newjeans', 'hype boy')
# ('nct wish', 'steady')                   ('newjeans', 'omg')
# ('nct wish', 'wish')                     ('newjeans', 'super shy')
# ('newjeans', 'attention')                ('niziu', 'heartris')
# ('newjeans', 'ditto')                    ('nmixx', 'dash')
# ('newjeans', 'eta')                      ('nmixx', 'love me like this')
# ('newjeans', 'how sweet')                ('nmixx', 'see that?')
# ('newjeans', 'hype boy')                 ('oh my girl', 'real love')
# ('newjeans', 'omg')                      ('oh my girl', 'summer comes')
# ('newjeans', 'super shy')                ('oneus', 'baila conmigo')
# ('niziu', 'heartris')                    ('oneus', 'erase me')
# ('nmixx', 'dash')                        ('oneus', 'same scent')
# ('nmixx', 'love me like this')           ('onew', 'o (circle)')
# ('nmixx', 'see that?')                   ('onf', 'bye my monster')
# ('oh my girl', 'real love')              ('p1harmony', "killin' it")
# ('oh my girl', 'summer comes')           ('p1harmony', 'sad song')
# ('oneus', 'baila conmigo')               ('pentagon', "feelin' like")
# ('oneus', 'erase me')                    ('plave', 'pump up the volume!')
# ('oneus', 'same scent')                  ('plave', 'way 4 luv')
# ('onew', 'o (circle)')                   ('psy feat. suga', 'that that (prod.&feat. suga of bts)')
# ('onf', 'bye my monster')                ('qwer', 'my name is malguem')
# ('p1harmony', "killin' it")              ('red velvet', 'birthday')
# ('p1harmony', 'sad song')                ('red velvet', 'chill kill')
# ('pentagon', "feelin' like")             ('red velvet', 'feel my rhythm')
# ('plave', 'pump up the volume')          ('riize', 'boom boom bass')
# ('plave', 'way 4 luv')                   ('riize', 'love 119')
# ('psy', 'that that')                     ('rosé', 'apt.')
# ('qwer', 'my name is malguem')           ('seventeen', 'god of music')
# ('red velvet', 'birthday')               ('seventeen', 'hot')
# ('red velvet', 'chill kill')             ('seventeen', 'love, money, fame (tak remix)')
# ('red velvet', 'feel my rhythm')         ('seventeen', 'maestro')
# ('riize', 'boom boom bass')              ('seventeen', 'super')
# ('riize', 'love 119')                    ('sf9', "don't worry, be happy (feat. jae yoon)")
# ('rosé&bruno mars', 'apt.')              ('shinee', 'hard')
# ('seventeen', '_world')                  ('small world', 'seventeen')
# ('seventeen', 'god of music')            ('solar', 'but i')
# ('seventeen', 'hot')                     ('stayc', 'beautiful monster')
# ('seventeen', 'love, money, fame')       ('stayc', 'bubble')
# ('seventeen', 'maestro')                 ('stayc', 'cheeky icy thang')
# ('seventeen', 'super')                   ('stayc', 'run2u')
# ('sf9', "don't worry, be happy")         ('stayc', 'teddy bear')
# ('shinee', 'hard')                       ('stray kids', 'case 143')
# ('solar', 'but i')                       ('stray kids', 'chk chk boom')
# ('stayc', 'beautiful monster')           ('stray kids', 'lalalala')
# ('stayc', 'bubble')                      ('stray kids', 'maniac')
# ('stayc', 'cheeky icy thang')            ('stray kids', 's-class')
# ('stayc', 'run2u')                       ('stray kids', 'walkin on water')
# ('stayc', 'teddy bear')                  ('taemin', 'guilty')
# ('stray kids', 'case 143')               ('taeyang feat. jimin', 'vibe (feat. jimin of bts)')
# ('stray kids', 'chk chk boom')           ('taeyeon', 'invu')
# ('stray kids', 'lalalala')               ('taeyeon', 'to. x')
# ('stray kids', 'maniac')                 ('tempest', 'dragon')
# ('stray kids', 's-class')                ('tempest', 'lighthouse')
# ('stray kids', 'walkin on water')        ('tempest', 'vroom vroom')
# ('taemin', 'guilty')                     ('the boyz', 'lip gloss')
# ('taeyang', 'vibe')                      ('the boyz', 'nectar')
# ('taeyeon', 'invu')                      ('the boyz', 'roar')
# ('taeyeon', 'to. x')                     ('the boyz', 'trigger')
# ('tempest', 'dragon')                    ('the boyz', 'watch it')
# ('tempest', 'lighthouse')                ('the boyz', 'whisper')
# ('tempest', 'vroom vroom')               ('the wind', 'hello, my first love')
# ('the boyz', 'lip gloss')                ('tomorrow x together', 'deja vu')
# ('the boyz', 'nectar')                   ('tomorrow x together', 'over the moon')
# ('the boyz', 'roar')                     ('tomorrow x together', 'sugar rush ride')
# ('the boyz', 'trigger')                  ('treasure', 'jikjin')
# ('the boyz', 'watch it')                 ('triples', 'girls never die')
# ('the boyz', 'whisper')                  ('triples', 'hit the floor')
# ('the wind', 'hello, my first love')     ('twice', 'set me free')
# ('tomorrow x together', 'deja vu')       ('twice', 'strategy')
# ('tomorrow x together', 'over the moon') ('tws', 'if i’m s, can you be my n?')
# ('tomorrow x together', 'sugar rush ride') ('tws', 'plot twist')
# ('treasure', 'jikjin')                   ('txt', 'good boy gone bad (unpopular theory remix)')
# ('triples', 'girls never die')           ('v', 'fri(end)s')
# ('triples', 'hit the floor')             ('v', 'love me again')
# ('twice', 'set me free')                 ('v', 'slow dancing')
# ('twice', 'strategy')                    ('vanner', 'automatic')
# ('tws', "if i'm s, can you be my n?")    ('verivery', 'tap tap')
# ('tws', 'plot twist')                    ('viva', 'chasing that feeling')
# ('txt', 'chasing that feeling')          ('viviz', 'bop bop!')
# ('txt', 'good boy gone bad')             ('wayv', 'frequency (超频率)')
# ('txt', 'sugar rush ride')               ('wayv', 'frequency - korean version')
# ('v', 'fri(end)s')                       ('wayv', 'give me that')
# ('v', 'love me again')                   ('wsg wannbe (gaya-g)', 'at that moment')
# ('v', 'slow dancing')                    ('yena feat. bibi', 'smiley (feat. bibi)')
# ('vanner', 'automatic')                  ('yeonjun', 'ggum')
# ('verivery', 'tap tap')                  ('younha', 'event horizon')
# ('viviz', 'bop bop!')                    ('zerobaseone', 'feel the pop')
# ('wayv', 'frequency')                    ('zerobaseone', 'good so bad')
# ('wayv', 'frequency(korean ver.)')       ('zerobaseone', 'in bloom')
# ('wayv', 'give me that')                 ('zico feat. jennie', 'spot!')
# ('wheein', 'make me happy')              -
# ('wsg wannabe (gaya-g)', 'at that moment') -
# ('yena', 'smiley')                       -
# ('yeonjun', 'ggum')                      -
# ('yooa', 'selfish')                      -
# ('younha', 'event horizon')              -
# ('zerobaseone', 'feel the pop')          -
# ('zerobaseone', 'good so bad')           -
# ('zerobaseone', 'in bloom')              -
# ('zico', 'spot!')                        -

# %% [markdown]
# **Wrong Search**
# - Seventeen - _World
# - Seventeen - love, money, fame is a remix
# - TXT - Good Boy Gone Bad is a remix
# - Jihyo - Killin' Me Good is english ver
# - TXT - Chasing That Feeling found a song by viva
# - Jhope Jcole song is just the solo
# - NCT - Songbird is the Japanese version
#
# **404 error**
# - Le Sserafim - Eve Psyche & Bluebeards Wife
# - Wheein - Make Me Happy **Doesn't appear to be in their catalog**
# - TXT - Sugar Rush Ride
# - CSR - ♡Ticon
# - Almost all of Fromis9 songs 3 (Songs)
# - lee gi-kwang - predator
# - Yooa - Selfish
#
# Insights Findings:
# - Wheein appears as Whee In
# - TXT can be found under TOMORROW X TOGETHER, which fixes all of their issues
# - ♡Ticon => LOVETICON
# - Fromis_9 songs have difficulty finding despite being a verified artist. Therefore, opting to use their artist id for their queries
# - Lee Gi-Kwang => LEEGIKWANG
# - Yooa => 유아
# - SEVENTEEN - _WORLD cannot be via queries so I found its trackID: 242182341
# - Most of the queries can be resolved using the track search endpoint instead of the matcher endpoint
# - Jihyo => Ji Hyo
# - Songbird => Songbird (Korean Version)

# %%
import requests
import urllib.parse

track = "Songbird (Korean)"
artist = "NCT"
APP_ID = "cf4d7395cd2d7f5618c4057426e93f26"
BASE_URL = "https://api.musixmatch.com/ws/1.1/"

## Matcher Query
query_url = f"{BASE_URL}matcher.track.get?apikey={APP_ID}&q_artist={artist}&q_track={track}&format=json"

## Track Search Query
query_url = f"{BASE_URL}track.search?apikey={APP_ID}&q_artist={artist}&q_track={track}&page_size=2&page=1&s_track_rating=desc&format=json"

## Find artist
# query_url = f"{BASE_URL}artist.search?apikey={APP_ID}&q_artist={artist}&page_size=1"

## Test Query
# query_url = f"{BASE_URL}track.search?apikey={APP_ID}&f_artist_id=34857912&q_track=menow&page_size=1&page=1&format=json"
# query_url = f"{BASE_URL}track.search?apikey={APP_ID}&f_artist_id=31899946&f_album_id=53067298&q_track=Circles&page_size=2&page=1&format=json"
# query_url = f"{BASE_URL}album.tracks.get?apikey={APP_ID}&album_id=53067298&page_size=2&page=1"

# Get mood values
query_url = f"{BASE_URL}track.lyrics.mood.get?apikey={APP_ID}&commontrack_id=5920049"



search = requests.get(query_url).json()
print(json.dumps(search, indent=4))
# Out:
# {
#     "message": {
#         "header": {
#             "status_code": 401,
#             "execute_time": 0.01217794418335,
#             "hint": "moods not enabled on this plan"
#         },
#         "body": []
#     }
# }

# %%
import requests

track = "Eve, Psyche & The Bluebeard's wife"
artist = "LE SSERAFIM"
APP_ID = "cf4d7395cd2d7f5618c4057426e93f26"
BASE_URL = "https://api.musixmatch.com/ws/1.1/"

## Matcher Query
# query_url = f"{BASE_URL}matcher.track.get?apikey={APP_ID}&q_artist={artist}&q_track={track}&format=json"

## Track Search Query
query_url = f"{BASE_URL}track.search?apikey={APP_ID}&q_artist={artist}&q_track={track}&format=json&page_size=1"

search = requests.get(query_url).json()
print(json.dumps(search, indent=4))
# Out:
# {
#     "message": {
#         "header": {
#             "status_code": 200,
#             "execute_time": 0.025938987731934,
#             "available": 5
#         },
#         "body": {
#             "track_list": [
#                 {
#                     "track": {
#                         "track_id": 256226625,
#                         "track_name": "Eve, Psyche & The Bluebeard\u2019s wife",
#                         "track_name_translation_list": [],
#                         "track_rating": 71,
#                         "commontrack_id": 159108270,
#                         "instrumental": 0,
#                         "explicit": 1,
#                         "has_lyrics": 1,
#                         "has_subtitles": 1,
#                         "has_richsync": 1,
#                         "num_favourite": 34,
#                         "album_id": 57090328,
#                         "album_name": "UNFORGIVEN",
#                         "artist_id": 53333048,
#                         "artist_name": "LE SSERAFIM",
#                         "track_share_url": "https://www.musixmatch.com/lyrics/LE-SSERAFIM/Eve-Psyche-The-Bluebeard-s-wife?utm_source=application&utm_campaign=api&utm_medium=Student+%2F+Self+Learner%3A1409625402262",
#                         "track_edit_url": "https://www.musixmatch.com/lyrics/LE-SSERAFIM/Eve-Psyche-The-Bluebeard-s-wife/edit?utm_source=application&utm_campaign=api&utm_medium=Student+%2F+Self+Learner%3A1409625402262",
#                         "restricted": 0,
#                         "updated_time": "2023-08-04T17:17:02Z",
#                         "primary_genres": {
#                             "music_genre_list": [
#                                 {
#                                     "music_genre": {
#                                         "music_genre_id": 14,
#                                         "music_genre_parent_id": 34,
#                                         "music_genre_name": "Pop",
#                                         "music_genre_name_extended": "Pop",
#                                         "music_genre_vanity": "Pop"
#                                     }
#                                 }
#                             ]
#                         }
#                     }
#                 }
#             ]
#         }
#     }
# }
